# %% [markdown]
# from...
# # [The Future 10: Get To Know These 10 Black Women In Tech](https://www.essence.com/news/money-career/black-women-working-in-tech/)
# Essence Magazine Online, Nov 2018

# %%
# importing libraries
import requests
import pandas as pd

# %%
# storing url
url = 'https://www.essence.com/news/money-career/black-women-working-in-tech/'

# %%
# storing html
html = requests.get(url).text

# %%
# looking at html
print(html)
# Out:
# <!-- static_get   key="403295" group="content/full-freestar/040" expires="Tue, 24 May 2022 08:00:43 +0000" now="Tue, 24 May 2022 07:58:12 +0000" -->
#
# <!doctype html>
# <html lang="en-US">
# <head>
# 	<meta charset="UTF-8"/><script type="text/javascript">(window.NREUM||(NREUM={})).init={privacy:{cookies_enabled:true},ajax:{deny_list:["bam-cell.nr-data.net"]}};(window.NREUM||(NREUM={})).loader_config={xpid:"VgUHVl9RDBACV1NaAAAOX1U=",licenseKey:"e0dca8d6e4",applicationID:"232871991"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var o=e[n]={exports:{}};t[n][0].call(o.exports,function(e){var o=t[n][1][e];return r(o||e)},o,o.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<n.length;o++)r(n[o]);return r}({1:[function(t,e,n){function r(t){try{s.console&&console.log(t)}catch(e){}}var o,i=t("ee"),a=t(31),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,o.indexOf("dev")!==-1&&(s.dev=!0),o.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&i.on("internal-error",function(t){r(t.stack)}),s.dev&&i.on("fn-err",function(t,e,n){r(n.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,s){try{l?l-=1:o(s||new UncaughtException(t,e,n),!0)}catch(f){try{i("ierr",[f,c.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,e,n){this.message=t||"Uncaught error with no additional information",this.sourceURL=e,this.line=n}function o(t,e){var n=e?null:c.now();i("err",[t,n])}var i=t("handle"),a=t(32),s=t("ee"),c=t("loader"),f=t("gos"),u=window.onerror,d=!1,p="nr@seenError";if(!c.disabled){var l=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(14),t(13),"addEventListener"in window&&t(7),c.xhrWrappable&&t(15),d=!0)}s.on("fn-start",function(t,e,n){d&&(l+=1)}),s.on("fn-err",function(t,e,n){d&&!n[p]&&(f(n,p,function(){return!0}),this.thrown=!0,o(n))}),s.on("fn-end",function(){d&&!this.thrown&&l>0&&(l-=1)}),s.on("internal-error",function(t){i("ierr",[t,c.now(),!0])})}},{}],3:[function(t,e,n){var r=t("loader");r.disabled||(r.features.ins=!0)},{}],4:[function(t,e,n){function r(){U++,L=g.hash,this[u]=y.now()}function o(){U--,g.hash!==L&&i(0,!0);var t=y.now();this[h]=~~this[h]+t-this[u],this[d]=t}function i(t,e){E.emit("newURL",[""+g,e])}function a(t,e){t.on(e,function(){this[e]=y.now()})}var s="-start",c="-end",f="-body",u="fn"+s,d="fn"+c,p="cb"+s,l="cb"+c,h="jsTime",m="fetch",v="addEventListener",w=window,g=w.location,y=t("loader");if(w[v]&&y.xhrWrappable&&!y.disabled){var x=t(11),b=t(12),E=t(9),R=t(7),O=t(14),T=t(8),S=t(15),P=t(10),M=t("ee"),C=M.get("tracer"),N=t(23);t(17),y.features.spa=!0;var L,U=0;M.on(u,r),b.on(p,r),P.on(p,r),M.on(d,o),b.on(l,o),P.on(l,o),M.buffer([u,d,"xhr-resolved"]),R.buffer([u]),O.buffer(["setTimeout"+c,"clearTimeout"+s,u]),S.buffer([u,"new-xhr","send-xhr"+s]),T.buffer([m+s,m+"-done",m+f+s,m+f+c]),E.buffer(["newURL"]),x.buffer([u]),b.buffer(["propagate",p,l,"executor-err","resolve"+s]),C.buffer([u,"no-"+u]),P.buffer(["new-jsonp","cb-start","jsonp-error","jsonp-end"]),a(T,m+s),a(T,m+"-done"),a(P,"new-jsonp"),a(P,"jsonp-end"),a(P,"cb-start"),E.on("pushState-end",i),E.on("replaceState-end",i),w[v]("hashchange",i,N(!0)),w[v]("load",i,N(!0)),w[v]("popstate",function(){i(0,U>1)},N(!0))}},{}],5:[function(t,e,n){function r(){var t=new PerformanceObserver(function(t,e){var n=t.getEntries();s(v,[n])});try{t.observe({entryTypes:["resource"]})}catch(e){}}function o(t){if(s(v,[window.performance.getEntriesByType(w)]),window.performance["c"+p])try{window.performance[h](m,o,!1)}catch(t){}else try{window.performance[h]("webkit"+m,o,!1)}catch(t){}}function i(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var a=t("ee"),s=t("handle"),c=t(14),f=t(13),u=t(6),d=t(23),p="learResourceTimings",l="addEventListener",h="removeEventListener",m="resourcetimingbufferfull",v="bstResource",w="resource",g="-start",y="-end",x="fn"+g,b="fn"+y,E="bstTimer",R="pushState",O=t("loader");if(!O.disabled) ...
# 	<meta name="viewport" content="width=device-width, initial-scale=1"/>
# 	<link rel="profile" href="https://gmpg.org/xfn/11"/>
# 	<style type="text/css">
# 		.site-header{background:#fff;box-shadow:0px 0px 5px #00000029;position:fixed;top:0;width:100%;z-index:100000}@media only screen and (min-width: 1124px){.site-header.fixed .hamburger-menu,.site-header.fixed .site-subscribe__select{display:none}.site-header.fixed .site-branding-container{align-items:flex-end;display:flex;min-height:70px;position:relative}.site-header.fixed .site-subscribe{position:absolute;right:25px}}@media only screen and (min-width: 1124px)and (min-width: 1440px){.site-header.fixed .site-subscribe{right:50px}}@media only screen and (min-width: 1124px){.site-header.fixed .site-branding{padding:20px 0}}.site-branding-container{padding:0 25px}@media only screen and (min-width: 1440px){.site-branding-container{padding:0 50px}}.site-branding{align-items:center;display:flex;padding:20px 0 18px}@media only screen and (min-width: 1124px){.site-branding{padding:22px 0}}.hamburger-menu,.site-subscribe{flex:1}.hamburger-menu svg,.site-subscribe svg{cursor:pointer;display:block;height:22px;width:25px}@media only screen and (max-width: 1439px){.hamburger-menu svg{width:32px}}@media only screen and (max-width: 1124px){.hamburger-menu svg{width:22px}}.site-logo{text-align:center}.site-logo a{display:flex;color:inherit !important;justify-content:center}.site-logo svg{height:21px;width:auto}@media only screen and (min-width: 1124px){.site-logo svg{height:24px}}.site-header.fixed .site-logo svg{margin:0}@media only screen and (min-width: 1124px){.site-header.fixed .site-logo svg{height:21px}}@media only screen and (min-width: 1440px){.site-header.fixed .site-logo svg{height:26px}}.site-subscribe{align-items:center;display:flex;justify-content:flex-end}.site-subscribe__select{position:relative}.site-subscribe__select:hover .site-subscribe__select-dropdown{display:block}.site-subscribe__select+.search{margin-left:38px}@media only screen and (max-width: 1439px){.site-header.fixed .site-subscribe__select+.search svg{width:22px}}.site-subscribe__select-title{display:block;color:#c5178d;cursor:pointer;font-size:12px;font-weight:700;padding:5px 0}@media only screen and (min-width: 1124px){.site-subscribe__select-title{background:#c5178d;color:#fff;font-size:10px;font-weight:500;line-height:10px;width:80px;height:20px;text-align:center}}.site-subscribe__select-dropdown{background:#fff;box-shadow:0 3px 6px #00000029;display:none;font-size:11px;list-style:none;margin:0;padding:15px 5px;position:absolute;min-width:100%;z-index:1}@media only screen and (min-width: 1124px){.site-subscribe__select-dropdown{font-size:13px;padding:15px 10px}}.site-subscribe__select-dropdown a{color:inherit;display:block;font-weight:500}.site-subscribe__select-dropdown a:visited{color:inherit}.site-subscribe__select-dropdown a:hover{color:#c5178d}.site-subscribe__select-dropdown li{line-height:1}.site-subscribe__select-dropdown li+li{margin-top:15px}.hide-on-mobile,.desktop-only{display:none;visibility:hidden}.site-content{min-height:100rem}.covid-bar{display:block;font-size:0;text-align:center;background-color:#c5168d}.covid-bar img{max-height:65px}#onetrust-reject-all-handler{display:none !important}.top_board_message_text{text-align:center;padding:15px}.top_board_button{padding:5px;border-radius:0px;text-transform:uppercase;display:inline-block}@media screen and (min-width: 960px)and (max-width: 1280px){.top_board_button{font-size:15px}}.ad-position.dfp-ads-horizontal.leaderboard{margin:0;padding-top:25px;padding-bottom:25px;overflow:hidden;min-height:var(--leaderboard_min_height_desktop)}@media only screen and (max-width: 600px){.ad-position.dfp-ads-horizontal.leaderboard{padding-top:15px;padding-bottom:15px}}.ad-position.dfp-ads-horizontal.leaderboard.rendered{padding-top:25px;padding-bottom:25px}@media only screen and (max-width: 600px){.ad-position.dfp-ads-horizontal.leaderboard.rendered{padding-top:15px;padding-bottom:15px}}.ad-position.dfp-ads-horizontal.leaderboard.rendered.flex-leaderboard{width:100%;aspect-ratio:994/250;padding:0}.ad-position.dfp ...
# 	</style>
# 	<meta name='robots' content='index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1' />
# 	<script data-cfasync="false" type="text/javascript">
# 		// Creates the freestar variable on the Window of the page. If freestar is
# 		// already declared it will use that current state. If not it will default to
# 		// an empty object.
# 		var freestar = freestar || {};
#
# 		// Sets the time of the execution of this code for reporting.
# 		freestar.hitTime = Date.now();
#
# 		// Creates the key queue in the freestar object. This is used for queueing
# 		// code that needs to execute.
# 		freestar.queue = freestar.queue || [];
#
# 		// Creates the key object config.
# 		freestar.config = freestar.config || {};
#
# 		// Creates a key debug which is used for testing and, or staging.
# 		freestar.debug = window.location.search.indexOf('fsdebug') === -1 ? false : true;
#
# 		// The body tags will push the ad slots into this array and they will be sent
# 		// to the adserver.
# 		freestar.config.enabled_slots = [
# 					];
#
# 		freestar.config.channel = "news"
#
# 		// Fetching of the pubfig script. Do not change from what was given to you by
# 		// your account representative.
# 		!function(a,b){var c=b.getElementsByTagName("script")[0],d=b.createElement("script"),e="https://a.pub.network/essence-com";e+=freestar.debug?"/qa/pubfig.min.js":"/pubfig.min.js",d.async=!0,d.src=e,c.parentNode.insertBefore(d,c)}(window,document);
#
# 		// Use callback on initial page load to ensure scripts are ready.
# 		// The newAdSlots method will then call the array to fetch the ads.
# 		// This is called in admanager.js, so comment out here.
# 		// freestar.initCallback = function () { (freestar.config.enabled_slots.length === 0) ? freestar.initCallbackCalled = false : freestar.newAdSlots(freestar.config.enabled_slots) }
#
# 	</script>
#
# 	<!-- This site is optimized with the Yoast SEO Premium plugin v17.7 (Yoast SEO v18.7) - https://yoast.com/wordpress/plugins/seo/ -->
# 	<title>The Future 10: Get To Know These 10 Black Women In Tech - Essence</title>
# 	<meta name="description" content="Forget about those depressing stats: These sisters prove that there’s room for us at the table." />
# 	<link rel="canonical" href="https://www.essence.com/news/money-career/black-women-working-in-tech/" />
# 	<meta property="og:locale" content="en_US" />
# 	<meta property="og:type" content="article" />
# 	<meta property="og:title" content="The Future 10: Get To Know These 10 Black Women In Tech" />
# 	<meta property="og:description" content="Forget about those depressing stats: These sisters prove that there’s room for us at the table." />
# 	<meta property="og:url" content="https://www.essence.com/news/money-career/black-women-working-in-tech/" />
# 	<meta property="og:site_name" content="Essence" />
# 	<meta property="article:publisher" content="https://www.facebook.com/essence" />
# 	<meta property="article:modified_time" content="2020-10-23T21:30:28+00:00" />
# 	<meta property="og:image" content="https://www.essence.com/wp-content/uploads/2018/11/GettyImages-906798272-900x600.jpg" />
# 	<meta name="twitter:card" content="summary_large_image" />
# 	<meta name="twitter:title" content="The Future 10: Get To Know These 10 Black Women In Tech" />
# 	<meta name="twitter:image" content="https://www.essence.com/wp-content/uploads/2018/11/GettyImages-906798272-1044x783.jpg" />
# 	<meta name="twitter:site" content="@essence" />
# 	<meta name="twitter:label1" content="Est. reading time" />
# 	<meta name="twitter:data1" content="6 minutes" />
# 	<!-- / Yoast SEO Premium plugin. -->
#
#
# <link rel='dns-prefetch' href='//www.essence.com' />
# <link rel='dns-prefetch' href='//cdn.parsely.com' />
# <link rel='dns-prefetch' href='//s.skimresources.com' />
# <link rel='dns-prefetch' href='//cdn.jwplayer.com' />
# <link rel='dns-prefetch' href='//cdn.adsafeprotected.com' />
# <link rel='dns-prefetch' href='//www.googletagservices.com' />
# <link rel='dns-prefetch' href='//s.w.org' />
# <link rel="alternate" type="application/rss+xml" title="Essence &raquo; Feed" href="https://www.essence.com/feed/" />
# <style id='wp-parsely-recommendations-style-inline-css' type='text/css'>
# .parsely-recommendations-list-title{font-size:1.2em}.parsely-recommendations-list{list-style:none;padding:unset}.parsely-recommendations-cardbody{overflow:hidden;padding:.8em;text-overflow:ellipsis;white-space:nowrap}.parsely-recommendations-cardmedia{padding:.8em .8em 0}
#
# </style>
# <link rel='stylesheet' id='essence_blocks-style-css-css'  href='https://www.essence.com/dist/blocks.style.build.css?ver=1652107395' type='text/css' media='all' />
# <style id='global-styles-inline-css' type='text/css'>
# body{--wp--preset--color--black: #000;--wp--preset--color--cyan-bluish-gray: #abb8c3;--wp--preset--color--white: #FFF;--wp--preset--color--pale-pink: #f78da7;--wp--preset--color--vivid-red: #cf2e2e;--wp--preset--color--luminous-vivid-orange: #ff6900;--wp--preset--color--luminous-vivid-amber: #fcb900;--wp--preset--color--light-green-cyan: #7bdcb5;--wp--preset--color--vivid-green-cyan: #00d084;--wp--preset--color--pale-cyan-blue: #8ed1fc;--wp--preset--color--vivid-cyan-blue: #0693e3;--wp--preset--color--vivid-purple: #9b51e0;--wp--preset--color--primary: #BD1187;--wp--preset--color--secondary: #3421e5;--wp--preset--color--ess-black: #161616;--wp--preset--color--light-gray: #f4f4f4;--wp--preset--gradient--vivid-cyan-blue-to-vivid-purple: linear-gradient(135deg,rgba(6,147,227,1) 0%,rgb(155,81,224) 100%);--wp--preset--gradient--light-green-cyan-to-vivid-green-cyan: linear-gradient(135deg,rgb(122,220,180) 0%,rgb(0,208,130) 100%);--wp--preset--gradient--luminous-vivid-amber-to-luminous-vivid-orange: linear-gradient(135deg,rgba(252,185,0,1) 0%,rgba(255,105,0,1) 100%);--wp--preset--gradient--luminous-vivid-orange-to-vivid-red: linear-gradient(135deg,rgba(255,105,0,1) 0%,rgb(207,46,46) 100%);--wp--preset--gradient--very-light-gray-to-cyan-bluish-gray: linear-gradient(135deg,rgb(238,238,238) 0%,rgb(169,184,195) 100%);--wp--preset--gradient--cool-to-warm-spectrum: linear-gradient(135deg,rgb(74,234,220) 0%,rgb(151,120,209) 20%,rgb(207,42,186) 40%,rgb(238,44,130) 60%,rgb(251,105,98) 80%,rgb(254,248,76) 100%);--wp--preset--gradient--blush-light-purple: linear-gradient(135deg,rgb(255,206,236) 0%,rgb(152,150,240) 100%);--wp--preset--gradient--blush-bordeaux: linear-gradient(135deg,rgb(254,205,165) 0%,rgb(254,45,45) 50%,rgb(107,0,62) 100%);--wp--preset--gradient--luminous-dusk: linear-gradient(135deg,rgb(255,203,112) 0%,rgb(199,81,192) 50%,rgb(65,88,208) 100%);--wp--preset--gradient--pale-ocean: linear-gradient(135deg,rgb(255,245,203) 0%,rgb(182,227,212) 50%,rgb(51,167,181) 100%);--wp--preset--gradient--electric-grass: linear-gradient(135deg,rgb(202,248,128) 0%,rgb(113,206,126) 100%);--wp--preset--gradient--midnight: linear-gradient(135deg,rgb(2,3,129) 0%,rgb(40,116,252) 100%);--wp--preset--duotone--dark-grayscale: url('#wp-duotone-dark-grayscale');--wp--preset--duotone--grayscale: url('#wp-duotone-grayscale');--wp--preset--duotone--purple-yellow: url('#wp-duotone-purple-yellow');--wp--preset--duotone--blue-red: url('#wp-duotone-blue-red');--wp--preset--duotone--midnight: url('#wp-duotone-midnight');--wp--preset--duotone--magenta-yellow: url('#wp-duotone-magenta-yellow');--wp--preset--duotone--purple-green: url('#wp-duotone-purple-green');--wp--preset--duotone--blue-orange: url('#wp-duotone-blue-orange');--wp--preset--font-size--small: 19.5px;--wp--preset--font-size--medium: 20px;--wp--preset--font-size--large: 36.5px;--wp--preset--font-size--x-large: 42px;--wp--preset--font-size--normal: 22px;--wp--preset--font-size--huge: 49.5px;}.has-black-color{color: var(--wp--preset--color--black) !important;}.has-cyan-bluish-gray-color{color: var(--wp--preset--color--cyan-bluish-gray) !important;}.has-white-color{color: var(--wp--preset--color--white) !important;}.has-pale-pink-color{color: var(--wp--preset--color--pale-pink) !important;}.has-vivid-red-color{color: var(--wp--preset--color--vivid-red) !important;}.has-luminous-vivid-orange-color{color: var(--wp--preset--color--luminous-vivid-orange) !important;}.has-luminous-vivid-amber-color{color: var(--wp--preset--color--luminous-vivid-amber) !important;}.has-light-green-cyan-color{color: var(--wp--preset--color--light-green-cyan) !important;}.has-vivid-green-cyan-color{color: var(--wp--preset--color--vivid-green-cyan) !important;}.has-pale-cyan-blue-color{color: var(--wp--preset--color--pale-cyan-blue) !important;}.has-vivid-cyan-blue-color{color: var(--wp--preset--color--vivid-cyan-blue) !important;}.has-vivid-purple-color{color: var(--wp--preset--color--vivid-purple) !important;}.has-black-backgroun ...
# </style>
# <link rel='stylesheet' id='essence_native_article-css'  href='https://www.essence.com/wp-content/plugins/essence-native-article/assets/css/frontend.css?ver=1653336755' type='text/css' media='all' />
# <link rel='stylesheet' id='essence-head-css-css'  href='https://www.essence.com/dist/head.701c0f825eaf68441fdf.css?ver=5.9.3' type='text/css' media='all' />
# <link rel='stylesheet' id='essence-print-style-css'  href='https://www.essence.com/wp-content/themes/essence/print.css?ver=1.1' type='text/css' media='print' />
# <script type='text/javascript' src='https://www.essence.com/wp-includes/js/jquery/jquery.min.js?ver=3.6.0' id='jquery-core-js'></script>
# <script type='text/javascript' src='https://www.essence.com/wp-includes/js/dist/vendor/regenerator-runtime.min.js?ver=0.13.9' id='regenerator-runtime-js'></script>
# <script type='text/javascript' src='https://www.essence.com/wp-includes/js/dist/vendor/wp-polyfill.min.js?ver=3.15.0' id='wp-polyfill-js'></script>
# <script type='text/javascript' src='//cdn.adsafeprotected.com/iasPET.1.js?ver=1.0' id='ess-ias-js-js'></script>
# <script type='text/javascript' src='https://www.googletagservices.com/tag/js/gpt.js?ver=5.9.3' async='async' id='ess-gpt-js-js'></script>
# <script type='text/javascript' id='ess-gpt-js-js-after'>
# var googletag = googletag || {};
# 			googletag.cmd = googletag.cmd || [];
# 			// Set up IAS pet.js
# 			var __iasPET = window.__iasPET || {};
# 			__iasPET.queue = __iasPET.queue || [];
# 			__iasPET.pubId = 929481;
# </script>
# <script type='text/javascript' id='essence-head-js-js-extra'>
# /* <![CDATA[ */
# var essence = {"ajaxUrl":"https:\/\/www.essence.com\/wp-admin\/admin-ajax.php","whichAd":"freestar","restUrl":"https:\/\/www.essence.com\/wp-json\/","post_id":"403295","srcUrl":"https:\/\/www.essence.com\/wp-content\/plugins\/essence-blocks\/"};
# var ess_iscroll = {"ess_iscroll_max":"6","ess_iscroll_video":"1","ess_iscroll_video_pos":"end","ess_iscroll_video1":"0","ess_iscroll_video2":"1","ess_injector_scope":"specific","ess_random_articles":[{"pos":"2","articles":[136807,31898,402765,405013,1136980,1136977,1138010,1138007,1139304],"type":"hot_video"},{"pos":"4","articles":[136807,31898,402765,405013,1136980,1136977,1138010,1138007,1139304],"type":"hot_video"},{"pos":"1","articles":[1166875,1166576,1165984,1165767,1161725,1161466,1163487,1162990],"type":"url"}],"type":"","ess_random_articles_enabled":"1"};
# var dfp_ad_object = [{"asynch":true,"account_id":"\/21698916284\/","slot_name":"ess\/news\/moneycareer","page_targeting":"{\"aid\":\"403295\",\"ctype\":\"article\",\"ch\":\"news\",\"tags\":[\"Black Women Working In Tech\",\"Careers\"],\"sch\":\"money-career\",\"cat\":\"ess apple\",\"kwblock\":[\"tst\",\"dis\",\"clx\",\"Bui\",\"Abb\",\"Microsoft\",\"Wal\",\"Air\",\"DIS 2\",\"CapOne\",\"CapOne2\",\"Coca\",\"UPS\",\"CricketAT&T\",\"ATTMob\",\"ATTCric\",\"mcd\",\"Targetbos\"]}","test":null}];
# var dataLayer = [{"gacd7":"own","gacd6":"11-09-2018","gacd9":"front end","gacd10":"essence.com","gacd1":"[Tamara E. Holmes]","gacd2":"News","gacd8":"article","gacd25":"403295","gacd3":"Money &amp; Career","gacd4":"Black-Women-Working-In-Tech,Careers"}];
# /* ]]> */
# </script>
# <script type='text/javascript' src='https://www.essence.com/dist/head.701c0f825eaf68441fdf.js?ver=5.9.3' id='essence-head-js-js'></script>
# <script type='text/javascript' id='essence-head-js-js-after'>
# (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-TJXBVJL');
# </script>
# <script type='text/javascript' src='https://cdn.jwplayer.com/libraries/t6KP9zcV.js?ver=5.9.3' id='jwplayer-js'></script>
# <script type='text/javascript' src='https://www.essence.com/dist/head_freestar.701c0f825eaf68441fdf.js?ver=5.9.3' id='essence-head-freestar-js-js'></script>
# <link rel="https://api.w.org/" href="https://www.essence.com/wp-json/" /><link rel="alternate" type="application/json" href="https://www.essence.com/wp-json/wp/v2/article/403295" /><link rel="EditURI" type="application/rsd+xml" title="RSD" href="https://www.essence.com/xmlrpc.php?rsd" />
# <link rel="wlwmanifest" type="application/wlwmanifest+xml" href="https://www.essence.com/wp-includes/wlwmanifest.xml" />
# <meta name="generator" content="WordPress 5.9.3" />
# <link rel='shortlink' href='https://www.essence.com/?p=403295' />
# <link rel="alternate" type="application/json+oembed" href="https://www.essence.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fwww.essence.com%2Fnews%2Fmoney-career%2Fblack-women-working-in-tech%2F" />
# <link rel="alternate" type="text/xml+oembed" href="https://www.essence.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fwww.essence.com%2Fnews%2Fmoney-career%2Fblack-women-working-in-tech%2F&#038;format=xml" />
# <script type="application/ld+json">
# {"@context":"https:\/\/schema.org","@type":"NewsArticle","mainEntityOfPage":{"@type":"WebPage","@id":"http:\/\/www.essence.com\/news\/money-career\/black-women-working-in-tech\/"},"headline":"The Future 10: Get To Know These 10 Black Women In Tech","url":"http:\/\/www.essence.com\/news\/money-career\/black-women-working-in-tech\/","thumbnailUrl":"","image":{"@type":"ImageObject","url":""},"dateCreated":"2018-11-09T17:22:07Z","datePublished":"2018-11-09T17:22:07Z","dateModified":"2020-10-23T21:30:28Z","articleSection":"News","author":[{"@type":"Person","name":"Tamara E. Holmes"}],"creator":["Tamara E. Holmes"],"publisher":{"@type":"Organization","name":"Essence","logo":"https:\/\/www.essence.com\/wp-content\/themes\/essence_theme\/assets\/images\/logo.png"},"keywords":["Black Women Working In Tech","Careers"]}
# </script>
# <style type="text/css">.recentcomments a{display:inline !important;padding:0 !important;margin:0 !important;}</style>			<meta property="og:type" content="article"/>
# 			<meta property="article:opinion" content="false"/>
# 			<meta property="fb:pages" content="68771922854"/>
# 			<meta property="article:content_tier" content="free"/>
# 						<script>
# 				window.fbAsyncInit = function () {
# 					FB.init({
# 						appId: '2453509358209265',
# 						autoLogAppEvents: true,
# 						xfbml: true,
# 						version: 'v3.2'
# 					});
# 				};
#
# 				(function (d, s, id) {
# 					var js, fjs = d.getElementsByTagName(s)[0];
# 					if (d.getElementById(id)) {
# 						return;
# 					}
# 					js = d.createElement(s);
# 					js.id = id;
# 					js.src = "https://connect.facebook.net/en_US/sdk.js";
# 					fjs.parentNode.insertBefore(js, fjs);
# 				}(document, 'script', 'facebook-jssdk'));
# 			</script>
# 			<link rel="amphtml" href="https://www.essence.com/news/money-career/black-women-working-in-tech/?amp=1"><link rel="icon" href="https://www.essence.com/wp-content/uploads/2018/04/cropped-essence-fav-icon-32x32.png" sizes="32x32" />
# <link rel="icon" href="https://www.essence.com/wp-content/uploads/2018/04/cropped-essence-fav-icon-192x192.png" sizes="192x192" />
# <link rel="apple-touch-icon" href="https://www.essence.com/wp-content/uploads/2018/04/cropped-essence-fav-icon-180x180.png" />
# <meta name="msapplication-TileImage" content="https://www.essence.com/wp-content/uploads/2018/04/cropped-essence-fav-icon-270x270.png" />
# 		<style type="text/css" id="wp-custom-css">
# 			.ad-position.dfp-ads-horizontal:before,
# .ad-position.dfp-ads-horizontal:after {
# 	display: none;
# }
#
# span.edit-link {
# 	display: none;
# }
# .logged-in span.edit-link {
# 	display: inline-block;
# }
# li#menu-item-515036 a {
#     background-image: url(https://www.essence.com/wp-content/uploads/2020/08/0920_LALA.jpg);
#     display: inline-block;
#     width: 238px;
#     height: 338px;
#     background-size: contain;
#     background-position: 0px 38px;
#     background-repeat: no-repeat;
# }
#
# #menu-item-515088 a {
#     background-color: #bd1187;
#     display: inline-block;
#     padding: 10px 9px;
#     border-radius: 2px;
#     color: #fff !important;
#     margin-top: 27px;
# }
#
# /* festival menu styles */
# .festival-logo img.card-img-top {
#     width: 180px;
#     margin-top: 10px;
# }
#
# #menu-festival-2022, #menu-festival-2020{
#     display: flex;
#     justify-content: center;
#     align-items: center;
# 	  position: relative;
#     right: 70px;
# 	z-index: 999;
# }
#
# .festival-menu li a {
#     color: #fff;
#     font-family: Gotham,Helvetica Neue,sans-serif;
#     text-decoration: none;
#     padding: 10px 20px;
#     font-size: 1.2em;
#     text-transform: uppercase;
#     font-weight: 700;
# }
#
# .festival-menu li ul.sub-menu {
#     background: #472f92;
#     padding: 2rem 0!important;
#     margin: 0 0 1rem;
#     z-index: 2;
#     display: none;
#     min-width: 250px;
# 	font-weight: 800;
# 	text-transform: uppercase;
#     Transition: .3s;
# }
#
# .festival-menu li ul.sub-menu li a {
#     color: #fff;
#     font-size: 14px;
#     padding: 0 2rem;
#     line-height: 2.5!important;
#     font-weight: 800;
# 	 text-transform: uppercase !important;
#     Transition: .3s;
# }
#
# #festival-navbar .dropdown-item:focus, #festival-navbar .dropdown-item:hover {
#     text-decoration: none;
#     background-color:#3b2779;
# }
#
# .festival-menu li ul.sub-menu li a:hover {
#     color:#ee3a92;
# }
#
# /*footer column title PB fix */
# #colophon .footer-magenta h6 {
#     padding-bottom: 0rem !important;
# }
#
# /* start black history month topic hide */
# .postid-411085 .single-topic .topics-header .swiper-container {
#     display: none;
# }
# /* end black history month topic hide */
#
#
# @media only screen and (max-width: 991px){
# .festival-menu li ul.sub-menu li a {
#     color: #fff!important;
#
# 	}
# #menu-festival-2022, #menu-festival-2020{
#     flex-direction:column;
#     justify-content: left;
# 	  right:0;
#
# }
# 	.festival-menu li ul.sub-menu {
#     position: relative;
#     margin-bottom: 0;
# }
# 	.festival-menu .menu-item-has-children>a {
#     justify-content: right;
# }
# 	.festival-menu li a {
#     padding: 10px 10px;
# 		text-align: left;
# }
# 	.festival-menu li ul.sub-menu {
#     background: transparent;
# }
# }
#
# @media screen and (max-width: 767px){
# .festival-menu li ul.sub-menu {
#     position: relative;
#     margin-bottom: 0;
# }
# 	.festival-menu .menu-item-has-children>a {
#     justify-content: right;
# }
# 		.festival-menu li a {
#     padding: 10px 10px;
#     text-align: left;
# }
# }		</style>
# 			</head>
#
# <body class="attachment article-template-default single single-article postid-403295 attachmentid-403295 attachment- wp-embed-responsive article black-women-working-in-tech second-menubar-article singular image-filters-enabled">
#
# <div id="fs-select-footer-remove"></div>
# 		<div id="essence_1x1"
# 			 class="ad-position essence_1x1 outofpage dfp-ads-outofpage"
# 			 data-placement-name="essence_1x1"
# 			 data-freestar-ad="__1x1"
# 	>
# 	</div>
# 	<div class="expanded-menu" style="display: none">
# 	<span class="close"><svg class="svg-icon" width="24" height="24" aria-hidden="true" role="img" focusable="false" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M19 6.41L17.59 5 12 10.59 6.41 5 5 6.41 10.59 12 5 17.59 6.41 19 12 13.41 17.59 19 19 17.59 13.41 12z"/><path d="M0 0h24v24H0z" fill="none"/></svg></span>
# 	<div class="logo">
# 		<a href="https://www.essence.com/" rel="home">
# 			<svg class="svg-icon" width="135" height="24" aria-hidden="true" role="img" focusable="false" width="351" height="60" viewBox="0 0 351 60" xmlns="http://www.w3.org/2000/svg"><path d="M0.379883 1.20001H40.6399V11.61H12.4899V23.98H40.0399V34.39H12.4899V47.61H40.6399V58.1H0.379883V1.20001Z"/><path d="M50.6998 40.86C54.7098 45.04 60.9398 48.53 68.7798 48.53C75.4298 48.53 78.6698 45.37 78.6698 42.13C78.6698 37.87 73.7298 36.42 67.1598 34.88C57.8698 32.74 45.9198 30.19 45.9198 17.48C45.9198 8.01 54.1098 0.339996 67.4998 0.339996C76.5398 0.339996 84.0398 3.07 89.6698 8.27L82.9398 17.14C78.3298 12.88 72.1998 10.91 66.6498 10.91C61.1898 10.91 58.2998 13.3 58.2998 16.71C58.2998 20.55 63.0798 21.74 69.6398 23.28C79.0298 25.42 90.9598 28.22 90.9598 40.85C90.9598 51.26 83.5398 59.1 68.1898 59.1C57.2798 59.1 49.4298 55.43 44.0498 50.06L50.6998 40.86Z"/><path d="M99.7298 40.86C103.74 45.04 109.97 48.53 117.81 48.53C124.46 48.53 127.7 45.37 127.7 42.13C127.7 37.87 122.75 36.42 116.19 34.88C106.9 32.74 94.9498 30.19 94.9498 17.48C94.9498 8.01 103.14 0.339996 116.53 0.339996C125.57 0.339996 133.07 3.07 138.7 8.27L131.97 17.14C127.36 12.88 121.23 10.91 115.68 10.91C110.22 10.91 107.33 13.3 107.33 16.71C107.33 20.55 112.11 21.74 118.67 23.28C128.06 25.42 139.99 28.22 139.99 40.85C139.99 51.26 132.57 59.1 117.22 59.1C106.31 59.1 98.4598 55.43 93.0798 50.06L99.7298 40.86Z"/><path d="M146.04 1.20001H186.3V11.61H158.15V23.98H185.7V34.39H158.15V47.61H186.3V58.1H146.04V1.20001Z"/><path d="M205.74 19.88V58.09H193.63V1.20001H206.08L232.43 38.04V1.20001H244.54V58.09H232.86L205.74 19.88Z"/><path d="M250.94 29.69C250.94 12.21 264.16 0.270004 280.79 0.270004C293.75 0.270004 301.01 7.09 305.01 14.17L294.6 19.28C292.21 14.67 287.1 11.01 280.78 11.01C270.89 11.01 263.38 18.95 263.38 29.69C263.38 40.43 270.88 48.37 280.78 48.37C287.09 48.37 292.21 44.79 294.6 40.1L305.01 45.13C300.92 52.21 293.75 59.12 280.79 59.12C264.16 59.11 250.94 47.16 250.94 29.69Z"/><path d="M310.13 1.20001H350.39V11.61H322.24V23.98H349.79V34.39H322.24V47.61H350.39V58.1H310.13V1.20001Z"/></svg>		</a>
# 	</div>
#
# 	<div class="site-search">
# 		<form action="https://www.essence.com/" method="GET">
# 			<input name="s" class="search" type="search" placeholder="SEARCH..." />
# 			<button type="submit"><span class="icon"><svg class="svg-icon" width="20" height="20" aria-hidden="true" role="img" focusable="false" xmlns="http://www.w3.org/2000/svg" width="25" height="25" viewBox="0 0 25 25"><path data-name="Search Icon" d="M10.612,18.03A8.073,8.073,0,0,1,2.5,10.012a8.113,8.113,0,0,1,16.225,0A8.077,8.077,0,0,1,10.612,18.03Zm13.6,4.04-5.774-5.713a9.911,9.911,0,0,0,2.294-6.346A10.07,10.07,0,0,0,10.612,0,10.067,10.067,0,0,0,.49,10.012a10.147,10.147,0,0,0,16.534,7.747L22.8,23.465a1,1,0,0,0,1.417,0A0.973,0.973,0,0,0,24.215,22.071Z"     transform="translate(-.5)" fill-rule="evenodd"/></svg></span></button>
# 		</form>
# 	</div>
# 	<div class="scroll-area">
# 		<div class="expanded-menu-container"><ul id="menu-expanded-menu" class="expanded-menu-menu"><li id="menu-item-1021682" class="menu-item menu-item-type-post_type menu-item-object-topic menu-item-has-children menu-item-1021682"><a href="https://www.essence.com/celebrity/" aria-haspopup="true" aria-expanded="false">Celebrity</a>
# <ul class="sub-menu">
# 	<li id="menu-item-1171685" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-1171685"><a href="https://www.essence.com/cardibandoffset/">Cardi B and Offset Cover</a></li>
# 	<li id="menu-item-1021683" class="menu-item menu-item-type-post_type menu-item-object-topic menu-item-1021683"><a href="https://www.essence.com/celebrity/">Celebrity News</a></li>
# 	<li id="menu-item-1021684" class="menu-item menu-item-type-custom menu-item-object-custom menu-item-1
class="menu-item menu-item-type-custom menu-item-object-custom menu-item-1021777"><a href="https://protect-us.mimecast.com/s/OAT5COYo9Bf7GX8IEIbVO?domain=subs.essence.com">Subscribe</a></li>
# <li id="menu-item-1122246" class="menu-item menu-item-type-custom menu-item-object-custom menu-item-1122246"><a href="https://www.essence.com/newsletters">Newsletters</a></li>
# </ul></div>		<div class="expanded-footer">
# 						<ul class="footer-social-links">
# ...
#
# 													</div>
# 					</div>
# 							</div>
# 		</div>	<div id="essence_right_rail_sticky_21700271123-403295-1"
# 			 class="ad-position essence_right_rail_sticky dfp-ads-vertical-sticky vertical-desktop-sticky"
# 			 data-placement-name="essence_right_rail_sticky"
# 			 data-freestar-ad="__300x600"
# 	>
# 	</div>
# <div class="sticky-ad-spacer"></div></div><!-- .entry-rightrail -->
# 			</div><!-- .entry-content -->
#
#
# 		  <div class="gtm-visibility-trigger" style="top: 10%"></div>
#
#
# 		  <div class="gtm-visibility-trigger" style="top: 30%"></div>
#
#
# 		  <div class="gtm-visibility-trigger" style="top: 50%"></div>
#
# 				</article><!-- #post-${post_id} -->
#
#
# 	<div class="essence-infinite-scroll">
# 		 <svg id="svgspin" xmlns="http://www.w3.org/2000/svg" width="50" height="50" viewBox="0 0 16 16"><path d="m8 0c-4.42 0-8 3.58-8 8s3.58 8 8 8 8-3.58 8-8-3.58-8-8-8m4.88 9.21c-.57 2.23-2.58 3.79-4.88 3.79s-4.31-1.56-4.88-3.79c-.1-.38.13-.76.51-.86.06-.02.12-.02.18-.02.32 0 .6.22.68.53.41 1.61 1.86 2.73 3.52 2.73s3.1-1.12 3.52-2.73c.08-.31.36-.53.68-.53.06 0 .12.001.18.02.18.05.34.16.43.33s.12.35.07.54"></path></svg>
# 	</div>
#
# 	<!-- static_end key="403295" group="content/full-freestar/040" -->
#
# 		</main><!-- #main -->
# 	</section><!-- #primary -->
#
#
# </div><!-- #content -->
#
# <!-- static_get   key="footer" group="global/" expires="Mon, 30 May 2022 20:12:52 +0000" now="Tue, 24 May 2022 07:58:13 +0000" -->
# <!-- static_start key="footer" group="global/" created="Mon, 23 May 2022 20:12:52 +0000" -->
# 	<footer id="colophon" class="site-footer">
#
# <div class="footer-magenta lazy" data-background-image="https://www.essence.com/wp-content/themes/essence/assets/images/mobile-newsletter.png" role="complementary" aria-label="Footer">
# 	<div class="footer-container">
# 					<div class="footer-col-list footer__company-info">
# 				<div id="text-3" class=" widget_text"><h6 class="widget-title">COMPANY INFORMATION</h6>			<div class="textwidget"><ul>
# <li><a href="https://www.essence.com/about/">Our Company</a></li>
# <li><a href="https://subs.essence.com/servlet/CSGateway?cds_mag_code=ESS">Customer Service</a></li>
# <li><a href="https://www.essence.com/essence-ventures-1">Essence Ventures</a></li>
# <li><a href="https://subs.essence.com/servlet/CSGateway?cds_mag_code=ESS">Change Your Address</a></li>
# <li><a href="https://www.essence.com/about/contact/">Contact Us</a></li>
# <li><a href="https://www.essence.com/careers/">Job Opportunities</a></li>
# <li><a href="https://www.essence.com/interns">Internships</a></li>
g class="svg-icon" width="24" height="24" aria-hidden="true" role="img" focusable="false" viewBox="0 0 24 24" version="1.1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><path d="M21.8,8.001c0,0-0.195-1.378-0.795-1.985c-0.76-0.797-1.613-0.801-2.004-0.847c-2.799-0.202-6.997-0.202-6.997-0.202 h-0.009c0,0-4.198,0-6.997,0.202C4.608,5.216,3.756,5.22,2.995,6.016C2.395,6.623,2.2,8.001,2.2,8.001S2,9.62,2,11.238v1.517 c0,1.618,0.2,3.237,0.2,3.237s0.195,1.378,0.795,1.985c0.761,0.797,1.76,0.771,2.205,0.855c1.6,0.153,6.8,0.201,6.8,0.201 s4.203-0.006,7.001-0.209c0.391-0.047,1.243-0.051,2.004-0.847c0.6-0.607,0.795-1.985,0.795-1.985s0.2-1.618,0.2-3.237v-1.517 C22,9.62,21.8,8.001,21.8,8.001z M9.935,14.594l-0.001-5.62l5.404,2.82L9.935,14.594z"></path></svg></a></li>
# 							</ul>
# 		</div>
# 					<div class="footer-col-list footer__more">
# 				<div id="text-5" class=" widget_text"><h6 class="widget-title">MORE ON ESSENCE</h6>			<div class="textwidget"><ul>
# <li><a href="https://www.essence.com/">Home</a></li>
# <li><a href="https://www.essence.com/love-sex/">Love</a></li>
# <li><a href="https://www.essence.com/celebrity/">Celebrity</a></li>
# <li><a href="https://www.essence.com/beauty/">Beauty</a></li>
# <li><a href="https://www.essence.com/hair/">Hair</a></li>
# <li><a href="https://www.essence.com/fashion/">Fashion</a></li>
# <li><a href="http://www.essencefestival.com/">ESSENCE festival</a></li>
# </ul>
# </div>
# 		</div>			</div>
# 				<div class="site-info">
# 			<center>
# <p>ESSENCE.com is part of ESSENCE Communications, Inc.</p>
# <p>Essence may receive compensation for some links to products and services on this website.  Offers may be subject to change without notice.</p>
# <p>©2022 ESSENCE Communications Inc.  All Rights Reserved.  |  <a href="https://www.essence.com/privacy-policy/">Privacy Policy</a>  |  <a href="https://www.essence.com/terms-of-use/">Terms of Use</a>  |  <a href="https://www.essence.com/advertising-terms/">Essence.com Advertising Terms</a>
# <center>					</div><!-- .site-info -->
# 	</div>
# </div>
#
# 		<div class="footer-fixed lazy" data-background-image="https://www.essence.com/wp-content/themes/essence/assets/images/footer-bg-202101.jpg">
# 	<div class="footer-container">
# 	<div class="footer-col-list">
# 			<h6 class="col-header">Get The <b>ESSENCE Newsletter</b> and <br /><b>Special Offers</b> delivered to your inbox</h6>
# 			<form action="https://www.essence.com/newsletters" method="get">
# 				<div class="sec-form">
# 				<input type="email" name="email" placeholder="Email">
# 				<input type="hidden" name="source" value="EE_CMS_footer">
# 				<input type="submit" class="btn" value="Sign Up"/>
# 				</div>
# 				<p class="sec-terms">
# 				By clicking Sign Up, you agree to our
# 				<a  rel="noopener" href="https://www.essence.com/terms-of-use/">Terms of Use</a> and <a  rel="noopener" href="https://www.essence.com/privacy-policy/">Privacy Policy.</a>
# 				</p>
# 			</form>
# 		</div>
# 		<div class="footer-col-list">
# 			<h6 class="col-header">Get The <b>ESSENCE Magazine</b><br />by subscribing below</h6>
# 			<a  rel="noopener" href="https://subs.essence.com/pubs/EV/ESS/self_gift_subscriptions_abtest_v4.jsp?cds_page_id=251957&cds_mag_code=ESS&id=1628867182199&lsid=12251006221017503&vid=1" class="btn" target="_blank">subscribe now</a>
# 		</div>
# 	</div>
# </div>
# 	</footer><!-- #colophon -->
#
# 	</div><!-- #page -->
#
# 	<div id="amzn-assoc-ad-8c622602-e003-469e-86cf-8a3a87294d7f"></div>
# 	<!-- OneTrust Cookies Consent Notice -->
# 	<script src="https://cookie-cdn.cookiepro.com/scripttemplates/otSDKStub.js" type="text/javascript" charset="UTF-8"
# 			data-domain-script="313aff84-84ef-43eb-b58d-25db39701fed"></script>
# 	<!-- static_end key="footer" group="global/" -->
# <link rel='stylesheet' id='article-css-css'  href='https://www.essence.com/dist/article.701c0f825eaf68441fdf.css?ver=5.9.3' type='text/css' media='all' />
# <link rel='stylesheet' id='footer-css-css'  href='https://www.essence.com/dist/footer.701c0f825eaf68441fdf.css?ver=5.9.3' type='text/css' media='all' />
# <script type='text/javascript' id='essence_native_article-js-extra'>
# /* <![CDATA[ */
# var essence_native_article = {"ajax_url":"https:\/\/www.essence.com\/wp-admin\/admin-ajax.php"};
# /* ]]> */
# </script>
# <script type='text/javascript' src='https://www.essence.com/wp-content/plugins/essence-native-article/assets/js/frontend.js?ver=1653336755' id='essence_native_article-js'></script>
# <script type='text/javascript' src='https://www.essence.com/wp-includes/js/dist/hooks.min.js?ver=1e58c8c5a32b2e97491080c5b10dc71c' id='wp-hooks-js'></script>
# <script type='text/javascript' id='wp-parsely-loader-js-before'>
# window.wpParselyApiKey = 'essence.com';
# </script>
# <script type='text/javascript' src='https://www.essence.com/wp-content/plugins/wp-parsely/build/loader.js?ver=84ad2ee25e7d3d6bc2142b281f26aed8' id='wp-parsely-loader-js'></script>
# <script type='text/javascript' data-parsely-site="essence.com" src='https://cdn.parsely.com/keys/essence.com/p.js?ver=3.3.0' id="parsely-cfg"></script>
# <script type='text/javascript' src='https://www.essence.com/dist/footer.701c0f825eaf68441fdf.js' id='essence-footer-js-js'></script>
# <script type='text/javascript' src='https://www.essence.com/dist/article.701c0f825eaf68441fdf.js' id='essence-article-js-js'></script>
# <script type='text/javascript' id='essence-article-js-js-after'>
# setTimeout(function() {
#     jQuery(window).trigger("analytics:event:iscrollView", [0]);
# }, 2000);
# </script>
# <script type='text/javascript' src='//s.skimresources.com/js/127531X1589222.skimlinks.js?ver=5.9.3' async='async' id='essence-skimlinks-script-js'></script>
# 	<script>
# 		/(trident|msie)/i.test(navigator.userAgent) && document.getElementById && window.addEventListener && window.addEventListener("hashchange", function () {
# 			var t, e = location.hash.substring(1);
# 			/^[A-z0-9_-]+$/.test(e) && (t = document.getElementById(e)) && (/^(?:a|select|input|button|textarea)$/i.test(t.tagName) || (t.tabIndex = -1), t.focus())
# 		}, !1);
# 	</script>
# 			<script>
# 			var dc_seg = 774531784;
# 			var axel = Math.random() + '';
# 			var a = axel * 10000000000000;
# 			var dfp = document.createElement("IMG");
# 			dfp.setAttribute("src", "https://pubads.g.doubleclick.net/activity;dc_iu=/21698916284/DFPAudiencePixel;ord=" + a + ";dc_seg=" + dc_seg + "?");
# 			dfp.setAttribute("width", "1px");
# 			dfp.setAttribute("height", "1px");
# 			document.body.appendChild(dfp);
# 		</script>
#
# <!-- rendered env="live" time="829.47683334351ms" now="Tue, 24 May 2022 07:58:13 +0000" -->
# <script type="text/javascript">window.NREUM||(NREUM={});NREUM.info={"beacon":"bam-cell.nr-data.net","licenseKey":"e0dca8d6e4","applicationID":"232871991","transactionName":"Ml1QYEsAXBAEUhBcXgsXc1dNCF0NSkINW1YJXR9VSxVbAAlU","queueTime":0,"applicationTime":886,"atts":"HhpTFgMaTx4=","errorBeacon":"bam-cell.nr-data.net","agent":""}</script></body>
# </html>

# %%
# splitting html text into list of strings
html.split('\n')
# Out:
# ['',
#  '<!-- static_get   key="403295" group="content/full-freestar/040" expires="Tue, 24 May 2022 08:00:43 +0000" now="Tue, 24 May 2022 07:58:12 +0000" -->',
#  '',
#  '<!doctype html>',
#  '<html lang="en-US">',
#  '<head>',
#  '\t<meta charset="UTF-8"/><script type="text/javascript">(window.NREUM||(NREUM={})).init={privacy:{cookies_enabled:true},ajax:{deny_list:["bam-cell.nr-data.net"]}};(window.NREUM||(NREUM={})).loader_config={xpid:"VgUHVl9RDBACV1NaAAAOX1U=",licenseKey:"e0dca8d6e4",applicationID:"232871991"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var o=e[n]={exports:{}};t[n][0].call(o.exports,function(e){var o=t[n][1][e];return r(o||e)},o,o.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<n.length;o++)r(n[o]);return r}({1:[function(t,e,n){function r(t){try{s.console&&console.log(t)}catch(e){}}var o,i=t("ee"),a=t(31),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,o.indexOf("dev")!==-1&&(s.dev=!0),o.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&i.on("internal-error",function(t){r(t.stack)}),s.dev&&i.on("fn-err",function(t,e,n){r(n.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,s){try{l?l-=1:o(s||new UncaughtException(t,e,n),!0)}catch(f){try{i("ierr",[f,c.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,e,n){this.message=t||"Uncaught error with no additional information",this.sourceURL=e,this.line=n}function o(t,e){var n=e?null:c.now();i("err",[t,n])}var i=t("handle"),a=t(32),s=t("ee"),c=t("loader"),f=t("gos"),u=window.onerror,d=!1,p="nr@seenError";if(!c.disabled){var l=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(14),t(13),"addEventListener"in window&&t(7),c.xhrWrappable&&t(15),d=!0)}s.on("fn-start",function(t,e,n){d&&(l+=1)}),s.on("fn-err",function(t,e,n){d&&!n[p]&&(f(n,p,function(){return!0}),this.thrown=!0,o(n))}),s.on("fn-end",function(){d&&!this.thrown&&l>0&&(l-=1)}),s.on("internal-error",function(t){i("ierr",[t,c.now(),!0])})}},{}],3:[function(t,e,n){var r=t("loader");r.disabled||(r.features.ins=!0)},{}],4:[function(t,e,n){function r(){U++,L=g.hash,this[u]=y.now()}function o(){U--,g.hash!==L&&i(0,!0);var t=y.now();this[h]=~~this[h]+t-this[u],this[d]=t}function i(t,e){E.emit("newURL",[""+g,e])}function a(t,e){t.on(e,function(){this[e]=y.now()})}var s="-start",c="-end",f="-body",u="fn"+s,d="fn"+c,p="cb"+s,l="cb"+c,h="jsTime",m="fetch",v="addEventListener",w=window,g=w.location,y=t("loader");if(w[v]&&y.xhrWrappable&&!y.disabled){var x=t(11),b=t(12),E=t(9),R=t(7),O=t(14),T=t(8),S=t(15),P=t(10),M=t("ee"),C=M.get("tracer"),N=t(23);t(17),y.features.spa=!0;var L,U=0;M.on(u,r),b.on(p,r),P.on(p,r),M.on(d,o),b.on(l,o),P.on(l,o),M.buffer([u,d,"xhr-resolved"]),R.buffer([u]),O.buffer(["setTimeout"+c,"clearTimeout"+s,u]),S.buffer([u,"new-xhr","send-xhr"+s]),T.buffer([m+s,m+"-done",m+f+s,m+f+c]),E.buffer(["newURL"]),x.buffer([u]),b.buffer(["propagate",p,l,"executor-err","resolve"+s]),C.buffer([u,"no-"+u]),P.buffer(["new-jsonp","cb-start","jsonp-error","jsonp-end"]),a(T,m+s),a(T,m+"-done"),a(P,"new-jsonp"),a(P,"jsonp-end"),a(P,"cb-start"),E.on("pushState-end",i),E.on("replaceState-end",i),w[v]("hashchange",i,N(!0)),w[v]("load",i,N(!0)),w[v]("popstate",function(){i(0,U>1)},N(!0))}},{}],5:[function(t,e,n){function r(){var t=new PerformanceObserver(function(t,e){var n=t.getEntries();s(v,[n])});try{t.observe({entryTypes:["resource"]})}catch(e){}}function o(t){if(s(v,[window.performance.getEntriesByType(w)]),window.performance["c"+p])try{window.performance[h](m,o,!1)}catch(t){}else try{window.performance[h]("webkit"+m,o,!1)}catch(t){}}function i(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var a=t("ee"),s=t("handle"),c=t(14),f=t(13),u=t(6),d=t(23),p="learResourceTimings",l="addEventListener",h="removeEventListener",m="resourcetimingbufferfull",v="bstResource",w="resource",g="-start",y="-end",x="fn"+g,b="fn"+y,E="bstTimer",R="pushState",O=t("loader");if(!O.disabl ...
#  '\t<meta name="viewport" content="width=device-width, initial-scale=1"/>',
#  '\t<link rel="profile" href="https://gmpg.org/xfn/11"/>',
#  '\t<style type="text/css">',
#  '\t\t.site-header{background:#fff;box-shadow:0px 0px 5px #00000029;position:fixed;top:0;width:100%;z-index:100000}@media only screen and (min-width: 1124px){.site-header.fixed .hamburger-menu,.site-header.fixed .site-subscribe__select{display:none}.site-header.fixed .site-branding-container{align-items:flex-end;display:flex;min-height:70px;position:relative}.site-header.fixed .site-subscribe{position:absolute;right:25px}}@media only screen and (min-width: 1124px)and (min-width: 1440px){.site-header.fixed .site-subscribe{right:50px}}@media only screen and (min-width: 1124px){.site-header.fixed .site-branding{padding:20px 0}}.site-branding-container{padding:0 25px}@media only screen and (min-width: 1440px){.site-branding-container{padding:0 50px}}.site-branding{align-items:center;display:flex;padding:20px 0 18px}@media only screen and (min-width: 1124px){.site-branding{padding:22px 0}}.hamburger-menu,.site-subscribe{flex:1}.hamburger-menu svg,.site-subscribe svg{cursor:pointer;display:block;height:22px;width:25px}@media only screen and (max-width: 1439px){.hamburger-menu svg{width:32px}}@media only screen and (max-width: 1124px){.hamburger-menu svg{width:22px}}.site-logo{text-align:center}.site-logo a{display:flex;color:inherit !important;justify-content:center}.site-logo svg{height:21px;width:auto}@media only screen and (min-width: 1124px){.site-logo svg{height:24px}}.site-header.fixed .site-logo svg{margin:0}@media only screen and (min-width: 1124px){.site-header.fixed .site-logo svg{height:21px}}@media only screen and (min-width: 1440px){.site-header.fixed .site-logo svg{height:26px}}.site-subscribe{align-items:center;display:flex;justify-content:flex-end}.site-subscribe__select{position:relative}.site-subscribe__select:hover .site-subscribe__select-dropdown{display:block}.site-subscribe__select+.search{margin-left:38px}@media only screen and (max-width: 1439px){.site-header.fixed .site-subscribe__select+.search svg{width:22px}}.site-subscribe__select-title{display:block;color:#c5178d;cursor:pointer;font-size:12px;font-weight:700;padding:5px 0}@media only screen and (min-width: 1124px){.site-subscribe__select-title{background:#c5178d;color:#fff;font-size:10px;font-weight:500;line-height:10px;width:80px;height:20px;text-align:center}}.site-subscribe__select-dropdown{background:#fff;box-shadow:0 3px 6px #00000029;display:none;font-size:11px;list-style:none;margin:0;padding:15px 5px;position:absolute;min-width:100%;z-index:1}@media only screen and (min-width: 1124px){.site-subscribe__select-dropdown{font-size:13px;padding:15px 10px}}.site-subscribe__select-dropdown a{color:inherit;display:block;font-weight:500}.site-subscribe__select-dropdown a:visited{color:inherit}.site-subscribe__select-dropdown a:hover{color:#c5178d}.site-subscribe__select-dropdown li{line-height:1}.site-subscribe__select-dropdown li+li{margin-top:15px}.hide-on-mobile,.desktop-only{display:none;visibility:hidden}.site-content{min-height:100rem}.covid-bar{display:block;font-size:0;text-align:center;background-color:#c5168d}.covid-bar img{max-height:65px}#onetrust-reject-all-handler{display:none !important}.top_board_message_text{text-align:center;padding:15px}.top_board_button{padding:5px;border-radius:0px;text-transform:uppercase;display:inline-block}@media screen and (min-width: 960px)and (max-width: 1280px){.top_board_button{font-size:15px}}.ad-position.dfp-ads-horizontal.leaderboard{margin:0;padding-top:25px;padding-bottom:25px;overflow:hidden;min-height:var(--leaderboard_min_height_desktop)}@media only screen and (max-width: 600px){.ad-position.dfp-ads-horizontal.leaderboard{padding-top:15px;padding-bottom:15px}}.ad-position.dfp-ads-horizontal.leaderboard.rendered{padding-top:25px;padding-bottom:25px}@media only screen and (max-width: 600px){.ad-position.dfp-ads-horizontal.leaderboard.rendered{padding-top:15px;padding-bottom:15px}}.ad-position.dfp-ads-horizontal.leaderboard.rendered.flex-leaderboard{width:100%;aspect-ratio:994/250;padding:0}.ad-position ...
#  '\t</style>',
#  "\t<meta name='robots' content='index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1' />",
#  '\t<script data-cfasync="false" type="text/javascript">',
#  '\t\t// Creates the freestar variable on the Window of the page. If freestar is',
#  '\t\t// already declared it will use that current state. If not it will default to',
#  '\t\t// an empty object.',
#  '\t\tvar freestar = freestar || {};',
#  '',
#  '\t\t// Sets the time of the execution of this code for reporting.',
#  '\t\tfreestar.hitTime = Date.now();',
#  '',
#  '\t\t// Creates the key queue in the freestar object. This is used for queueing',
#  '\t\t// code that needs to execute.',
#  '\t\tfreestar.queue = freestar.queue || [];',
#  '',
#  '\t\t// Creates the key object config.',
#  '\t\tfreestar.config = freestar.config || {};',
#  '',
#  '\t\t// Creates a key debug which is used for testing and, or staging.',
#  "\t\tfreestar.debug = window.location.search.indexOf('fsdebug') === -1 ? false : true;",
#  '',
#  '\t\t// The body tags will push the ad slots into this array and they will be sent',
#  '\t\t// to the adserver.',
#  '\t\tfreestar.config.enabled_slots = [',
#  '\t\t\t\t\t];',
#  '',
#  '\t\tfreestar.config.channel = "news"',
#  '',
#  '\t\t// Fetching of the pubfig script. Do not change from what was given to you by',
#  '\t\t// your account representative.',
#  '\t\t!function(a,b){var c=b.getElementsByTagName("script")[0],d=b.createElement("script"),e="https://a.pub.network/essence-com";e+=freestar.debug?"/qa/pubfig.min.js":"/pubfig.min.js",d.async=!0,d.src=e,c.parentNode.insertBefore(d,c)}(window,document);',
#  '',
#  '\t\t// Use callback on initial page load to ensure scripts are ready.',
#  '\t\t// The newAdSlots method will then call the array to fetch the ads.',
#  '\t\t// This is called in admanager.js, so comment out here.',
#  '\t\t// freestar.initCallback = function () { (freestar.config.enabled_slots.length === 0) ? freestar.initCallbackCalled = false : freestar.newAdSlots(freestar.config.enabled_slots) }',
#  '',
#  '\t</script>',
#  '',
#  '\t<!-- This site is optimized with the Yoast SEO Premium plugin v17.7 (Yoast SEO v18.7) - https://yoast.com/wordpress/plugins/seo/ -->',
#  '\t<title>The Future 10: Get To Know These 10 Black Women In Tech - Essence</title>',
#  '\t<meta name="description" content="Forget about those depressing stats: These sisters prove that there’s room for us at the table." />',
#  '\t<link rel="canonical" href="https://www.essence.com/news/money-career/black-women-working-in-tech/" />',
#  '\t<meta property="og:locale" content="en_US" />',
#  '\t<meta property="og:type" content="article" />',
#  '\t<meta property="og:title" content="The Future 10: Get To Know These 10 Black Women In Tech" />',
#  '\t<meta property="og:description" content="Forget about those depressing stats: These sisters prove that there’s room for us at the table." />',
#  '\t<meta property="og:url" content="https://www.essence.com/news/money-career/black-women-working-in-tech/" />',
#  '\t<meta property="og:site_name" content="Essence" />',
#  '\t<meta property="article:publisher" content="https://www.facebook.com/essence" />',
#  '\t<meta property="article:modified_time" content="2020-10-23T21:30:28+00:00" />',
#  '\t<meta property="og:image" content="https://www.essence.com/wp-content/uploads/2018/11/GettyImages-906798272-900x600.jpg" />',
#  '\t<meta name="twitter:card" content="summary_large_image" />',
#  '\t<meta name="twitter:title" content="The Future 10: Get To Know These 10 Black Women In Tech" />',
#  '\t<meta name="twitter:image" content="https://www.essence.com/wp-content/uploads/2018/11/GettyImages-906798272-1044x783.jpg" />',
#  '\t<meta name="twitter:site" content="@essence" />',
#  '\t<meta name="twitter:label1" content="Est. reading time" />',
#  '\t<meta name="twitter:data1" content="6 minutes" />',
#  '\t<!-- / Yoast SEO Premium plugin. -->',
#  '',
#  '',
#  "<link rel='dns-prefetch' href='//www.essence.com' />",
#  "<link rel='dns-prefetch' href='//cdn.parsely.com' />",
#  "<link rel='dns-prefetch' href='//s.skimresources.com' />",
#  "<link rel='dns-prefetch' href='//cdn.jwplayer.com' />",
#  "<link rel='dns-prefetch' href='//cdn.adsafeprotected.com' />",
#  "<link rel='dns-prefetch' href='//www.googletagservices.com' />",
#  "<link rel='dns-prefetch' href='//s.w.org' />",
#  '<link rel="alternate" type="application/rss+xml" title="Essence &raquo; Feed" href="https://www.essence.com/feed/" />',
#  "<style id='wp-parsely-recommendations-style-inline-css' type='text/css'>",
#  '.parsely-recommendations-list-title{font-size:1.2em}.parsely-recommendations-list{list-style:none;padding:unset}.parsely-recommendations-cardbody{overflow:hidden;padding:.8em;text-overflow:ellipsis;white-space:nowrap}.parsely-recommendations-cardmedia{padding:.8em .8em 0}',
#  '',
#  '</style>',
#  "<link rel='stylesheet' id='essence_blocks-style-css-css'  href='https://www.essence.com/dist/blocks.style.build.css?ver=1652107395' type='text/css' media='all' />",
#  "<style id='global-styles-inline-css' type='text/css'>",
#  "body{--wp--preset--color--black: #000;--wp--preset--color--cyan-bluish-gray: #abb8c3;--wp--preset--color--white: #FFF;--wp--preset--color--pale-pink: #f78da7;--wp--preset--color--vivid-red: #cf2e2e;--wp--preset--color--luminous-vivid-orange: #ff6900;--wp--preset--color--luminous-vivid-amber: #fcb900;--wp--preset--color--light-green-cyan: #7bdcb5;--wp--preset--color--vivid-green-cyan: #00d084;--wp--preset--color--pale-cyan-blue: #8ed1fc;--wp--preset--color--vivid-cyan-blue: #0693e3;--wp--preset--color--vivid-purple: #9b51e0;--wp--preset--color--primary: #BD1187;--wp--preset--color--secondary: #3421e5;--wp--preset--color--ess-black: #161616;--wp--preset--color--light-gray: #f4f4f4;--wp--preset--gradient--vivid-cyan-blue-to-vivid-purple: linear-gradient(135deg,rgba(6,147,227,1) 0%,rgb(155,81,224) 100%);--wp--preset--gradient--light-green-cyan-to-vivid-green-cyan: linear-gradient(135deg,rgb(122,220,180) 0%,rgb(0,208,130) 100%);--wp--preset--gradient--luminous-vivid-amber-to-luminous-vivid-orange: linear-gradient(135deg,rgba(252,185,0,1) 0%,rgba(255,105,0,1) 100%);--wp--preset--gradient--luminous-vivid-orange-to-vivid-red: linear-gradient(135deg,rgba(255,105,0,1) 0%,rgb(207,46,46) 100%);--wp--preset--gradient--very-light-gray-to-cyan-bluish-gray: linear-gradient(135deg,rgb(238,238,238) 0%,rgb(169,184,195) 100%);--wp--preset--gradient--cool-to-warm-spectrum: linear-gradient(135deg,rgb(74,234,220) 0%,rgb(151,120,209) 20%,rgb(207,42,186) 40%,rgb(238,44,130) 60%,rgb(251,105,98) 80%,rgb(254,248,76) 100%);--wp--preset--gradient--blush-light-purple: linear-gradient(135deg,rgb(255,206,236) 0%,rgb(152,150,240) 100%);--wp--preset--gradient--blush-bordeaux: linear-gradient(135deg,rgb(254,205,165) 0%,rgb(254,45,45) 50%,rgb(107,0,62) 100%);--wp--preset--gradient--luminous-dusk: linear-gradient(135deg,rgb(255,203,112) 0%,rgb(199,81,192) 50%,rgb(65,88,208) 100%);--wp--preset--gradient--pale-ocean: linear-gradient(135deg,rgb(255,245,203) 0%,rgb(182,227,212) 50%,rgb(51,167,181) 100%);--wp--preset--gradient--electric-grass: linear-gradient(135deg,rgb(202,248,128) 0%,rgb(113,206,126) 100%);--wp--preset--gradient--midnight: linear-gradient(135deg,rgb(2,3,129) 0%,rgb(40,116,252) 100%);--wp--preset--duotone--dark-grayscale: url('#wp-duotone-dark-grayscale');--wp--preset--duotone--grayscale: url('#wp-duotone-grayscale');--wp--preset--duotone--purple-yellow: url('#wp-duotone-purple-yellow');--wp--preset--duotone--blue-red: url('#wp-duotone-blue-red');--wp--preset--duotone--midnight: url('#wp-duotone-midnight');--wp--preset--duotone--magenta-yellow: url('#wp-duotone-magenta-yellow');--wp--preset--duotone--purple-green: url('#wp-duotone-purple-green');--wp--preset--duotone--blue-orange: url('#wp-duotone-blue-orange');--wp--preset--font-size--small: 19.5px;--wp--preset--font-size--medium: 20px;--wp--preset--font-size--large: 36.5px;--wp--preset--font-size--x-large: 42px;--wp--preset--font-size--normal: 22px;--wp--preset--font-size--huge: 49.5px;}.has-black-color{color: var(--wp--preset--color--black) !important;}.has-cyan-bluish-gray-color{color: var(--wp--preset--color--cyan-bluish-gray) !important;}.has-white-color{color: var(--wp--preset--color--white) !important;}.has-pale-pink-color{color: var(--wp--preset--color--pale-pink) !important;}.has-vivid-red-color{color: var(--wp--preset--color--vivid-red) !important;}.has-luminous-vivid-orange-color{color: var(--wp--preset--color--luminous-vivid-orange) !important;}.has-luminous-vivid-amber-color{color: var(--wp--preset--color--luminous-vivid-amber) !important;}.has-light-green-cyan-color{color: var(--wp--preset--color--light-green-cyan) !important;}.has-vivid-green-cyan-color{color: var(--wp--preset--color--vivid-green-cyan) !important;}.has-pale-cyan-blue-color{color: var(--wp--preset--color--pale-cyan-blue) !important;}.has-vivid-cyan-blue-color{color: var(--wp--preset--color--vivid-cyan-blue) !important;}.has-vivid-purple-color{color: var(--wp--preset--color--vivid-purple) !important;}.has-black-backgro ...
#  '</style>',
#  "<link rel='stylesheet' id='essence_native_article-css'  href='https://www.essence.com/wp-content/plugins/essence-native-article/assets/css/frontend.css?ver=1653336755' type='text/css' media='all' />",
#  "<link rel='stylesheet' id='essence-head-css-css'  href='https://www.essence.com/dist/head.701c0f825eaf68441fdf.css?ver=5.9.3' type='text/css' media='all' />",
#  "<link rel='stylesheet' id='essence-print-style-css'  href='https://www.essence.com/wp-content/themes/essence/print.css?ver=1.1' type='text/css' media='print' />",
#  "<script type='text/javascript' src='https://www.essence.com/wp-includes/js/jquery/jquery.min.js?ver=3.6.0' id='jquery-core-js'></script>",
#  "<script type='text/javascript' src='https://www.essence.com/wp-includes/js/dist/vendor/regenerator-runtime.min.js?ver=0.13.9' id='regenerator-runtime-js'></script>",
#  "<script type='text/javascript' src='https://www.essence.com/wp-includes/js/dist/vendor/wp-polyfill.min.js?ver=3.15.0' id='wp-polyfill-js'></script>",
#  "<script type='text/javascript' src='//cdn.adsafeprotected.com/iasPET.1.js?ver=1.0' id='ess-ias-js-js'></script>",
#  "<script type='text/javascript' src='https://www.googletagservices.com/tag/js/gpt.js?ver=5.9.3' async='async' id='ess-gpt-js-js'></script>",
#  "<script type='text/javascript' id='ess-gpt-js-js-after'>",
#  'var googletag = googletag || {};',
#  '\t\t\tgoogletag.cmd = googletag.cmd || [];',
#  '\t\t\t// Set up IAS pet.js',
#  '\t\t\tvar __iasPET = window.__iasPET || {};',
#  '\t\t\t__iasPET.queue = __iasPET.queue || [];',
#  '\t\t\t__iasPET.pubId = 929481;',
#  '</script>',
#  "<script type='text/javascript' id='essence-head-js-js-extra'>",
#  '/* <![CDATA[ */',
#  'var essence = {"ajaxUrl":"https:\\/\\/www.essence.com\\/wp-admin\\/admin-ajax.php","whichAd":"freestar","restUrl":"https:\\/\\/www.essence.com\\/wp-json\\/","post_id":"403295","srcUrl":"https:\\/\\/www.essence.com\\/wp-content\\/plugins\\/essence-blocks\\/"};',
#  'var ess_iscroll = {"ess_iscroll_max":"6","ess_iscroll_video":"1","ess_iscroll_video_pos":"end","ess_iscroll_video1":"0","ess_iscroll_video2":"1","ess_injector_scope":"specific","ess_random_articles":[{"pos":"2","articles":[136807,31898,402765,405013,1136980,1136977,1138010,1138007,1139304],"type":"hot_video"},{"pos":"4","articles":[136807,31898,402765,405013,1136980,1136977,1138010,1138007,1139304],"type":"hot_video"},{"pos":"1","articles":[1166875,1166576,1165984,1165767,1161725,1161466,1163487,1162990],"type":"url"}],"type":"","ess_random_articles_enabled":"1"};',
#  'var dfp_ad_object = [{"asynch":true,"account_id":"\\/21698916284\\/","slot_name":"ess\\/news\\/moneycareer","page_targeting":"{\\"aid\\":\\"403295\\",\\"ctype\\":\\"article\\",\\"ch\\":\\"news\\",\\"tags\\":[\\"Black Women Working In Tech\\",\\"Careers\\"],\\"sch\\":\\"money-career\\",\\"cat\\":\\"ess apple\\",\\"kwblock\\":[\\"tst\\",\\"dis\\",\\"clx\\",\\"Bui\\",\\"Abb\\",\\"Microsoft\\",\\"Wal\\",\\"Air\\",\\"DIS 2\\",\\"CapOne\\",\\"CapOne2\\",\\"Coca\\",\\"UPS\\",\\"CricketAT&T\\",\\"ATTMob\\",\\"ATTCric\\",\\"mcd\\",\\"Targetbos\\"]}","test":null}];',
#  'var dataLayer = [{"gacd7":"own","gacd6":"11-09-2018","gacd9":"front end","gacd10":"essence.com","gacd1":"[Tamara E. Holmes]","gacd2":"News","gacd8":"article","gacd25":"403295","gacd3":"Money &amp; Career","gacd4":"Black-Women-Working-In-Tech,Careers"}];',
#  '/* ]]> */',
#  '</script>',
#  "<script type='text/javascript' src='https://www.essence.com/dist/head.701c0f825eaf68441fdf.js?ver=5.9.3' id='essence-head-js-js'></script>",
#  "<script type='text/javascript' id='essence-head-js-js-after'>",
#  "(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':",
#  "new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],",
#  "j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=",
#  "'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);",
#  "})(window,document,'script','dataLayer','GTM-TJXBVJL');",
#  '</script>',
#  "<script type='text/javascript' src='https://cdn.jwplayer.com/libraries/t6KP9zcV.js?ver=5.9.3' id='jwplayer-js'></script>",
#  "<script type='text/javascript' src='https://www.essence.com/dist/head_freestar.701c0f825eaf68441fdf.js?ver=5.9.3' id='essence-head-freestar-js-js'></script>",
#  '<link rel="https://api.w.org/" href="https://www.essence.com/wp-json/" /><link rel="alternate" type="application/json" href="https://www.essence.com/wp-json/wp/v2/article/403295" /><link rel="EditURI" type="application/rsd+xml" title="RSD" href="https://www.essence.com/xmlrpc.php?rsd" />',
#  '<link rel="wlwmanifest" type="application/wlwmanifest+xml" href="https://www.essence.com/wp-includes/wlwmanifest.xml" /> ',
#  '<meta name="generator" content="WordPress 5.9.3" />',
#  "<link rel='shortlink' href='https://www.essence.com/?p=403295' />",
#  '<link rel="alternate" type="application/json+oembed" href="https://www.essence.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fwww.essence.com%2Fnews%2Fmoney-career%2Fblack-women-working-in-tech%2F" />',
#  '<link rel="alternate" type="text/xml+oembed" href="https://www.essence.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fwww.essence.com%2Fnews%2Fmoney-career%2Fblack-women-working-in-tech%2F&#038;format=xml" />',
#  '<script type="application/ld+json">',
#  '{"@context":"https:\\/\\/schema.org","@type":"NewsArticle","mainEntityOfPage":{"@type":"WebPage","@id":"http:\\/\\/www.essence.com\\/news\\/money-career\\/black-women-working-in-tech\\/"},"headline":"The Future 10: Get To Know These 10 Black Women In Tech","url":"http:\\/\\/www.essence.com\\/news\\/money-career\\/black-women-working-in-tech\\/","thumbnailUrl":"","image":{"@type":"ImageObject","url":""},"dateCreated":"2018-11-09T17:22:07Z","datePublished":"2018-11-09T17:22:07Z","dateModified":"2020-10-23T21:30:28Z","articleSection":"News","author":[{"@type":"Person","name":"Tamara E. Holmes"}],"creator":["Tamara E. Holmes"],"publisher":{"@type":"Organization","name":"Essence","logo":"https:\\/\\/www.essence.com\\/wp-content\\/themes\\/essence_theme\\/assets\\/images\\/logo.png"},"keywords":["Black Women Working In Tech","Careers"]}',
#  '</script>',
#  '<style type="text/css">.recentcomments a{display:inline !important;padding:0 !important;margin:0 !important;}</style>\t\t\t<meta property="og:type" content="article"/>',
#  '\t\t\t<meta property="article:opinion" content="false"/>',
#  '\t\t\t<meta property="fb:pages" content="68771922854"/>',
#  '\t\t\t<meta property="article:content_tier" content="free"/>',
#  '\t\t\t\t\t\t<script>',
#  '\t\t\t\twindow.fbAsyncInit = function () {',
#  '\t\t\t\t\tFB.init({',
#  "\t\t\t\t\t\tappId: '2453509358209265',",
#  '\t\t\t\t\t\tautoLogAppEvents: true,',
#  '\t\t\t\t\t\txfbml: true,',
#  "\t\t\t\t\t\tversion: 'v3.2'",
#  '\t\t\t\t\t});',
#  '\t\t\t\t};',
#  '',
#  '\t\t\t\t(function (d, s, id) {',
#  '\t\t\t\t\tvar js, fjs = d.getElementsByTagName(s)[0];',
#  '\t\t\t\t\tif (d.getElementById(id)) {',
#  '\t\t\t\t\t\treturn;',
#  '\t\t\t\t\t}',
#  '\t\t\t\t\tjs = d.createElement(s);',
#  '\t\t\t\t\tjs.id = id;',
#  '\t\t\t\t\tjs.src = "https://connect.facebook.net/en_US/sdk.js";',
#  '\t\t\t\t\tfjs.parentNode.insertBefore(js, fjs);',
#  "\t\t\t\t}(document, 'script', 'facebook-jssdk'));",
#  '\t\t\t</script>',
#  '\t\t\t<link rel="amphtml" href="https://www.essence.com/news/money-career/black-women-working-in-tech/?amp=1"><link rel="icon" href="https://www.essence.com/wp-content/uploads/2018/04/cropped-essence-fav-icon-32x32.png" sizes="32x32" />',
#  '<link rel="icon" href="https://www.essence.com/wp-content/uploads/2018/04/cropped-essence-fav-icon-192x192.png" sizes="192x192" />',
#  '<link rel="apple-touch-icon" href="https://www.essence.com/wp-content/uploads/2018/04/cropped-essence-fav-icon-180x180.png" />',
#  '<meta name="msapplication-TileImage" content="https://www.essence.com/wp-content/uploads/2018/04/cropped-essence-fav-icon-270x270.png" />',
#  '\t\t<style type="text/css" id="wp-custom-css">',
#  '\t\t\t.ad-position.dfp-ads-horizontal:before,',
#  '.ad-position.dfp-ads-horizontal:after {',
#  '\tdisplay: none;',
#  '}',
#  '',
#  'span.edit-link {',
#  '\tdisplay: none;',
#  '}',
#  '.logged-in span.edit-link {',
#  '\tdisplay: inline-block;',
#  '}',
#  'li#menu-item-515036 a {',
#  '    background-image: url(https://www.essence.com/wp-content/uploads/2020/08/0920_LALA.jpg);',
#  '    display: inline-block;',
#  '    width: 238px;',
#  '    height: 338px;',
#  '    background-size: contain;',
#  '    background-position: 0px 38px;',
#  '    background-repeat: no-repeat;',
#  '}',
#  '',
#  '#menu-item-515088 a {',
#  '    background-color: #bd1187;',
#  '    display: inline-block;',
#  '    padding: 10px 9px;',
#  '    border-radius: 2px;',
#  '    color: #fff !important;',
#  '    margin-top: 27px;',
#  '}',
#  '',
#  '/* festival menu styles */',
#  '.festival-logo img.card-img-top {',
#  '    width: 180px;',
#  '    margin-top: 10px;',
#  '}',
#  '',
#  '#menu-festival-2022, #menu-festival-2020{',
#  '    display: flex;',
#  '    justify-content: center;',
#  '    align-items: center; ',
#  '\t  position: relative;',
#  '    right: 70px;',
#  '\tz-index: 999;',
#  '}',
#  '',
#  '.festival-menu li a {',
#  '    color: #fff;',
#  '    font-family: Gotham,Helvetica Neue,sans-serif;',
#  '    text-decoration: none;',
#  '    padding: 10px 20px;',
#  '    font-size: 1.2em;',
#  '    text-transform: uppercase;',
#  '    font-weight: 700;',
#  '}',
#  '',
#  '.festival-menu li ul.sub-menu {',
#  '    background: #472f92;',
#  '    padding: 2rem 0!important;',
#  '    margin: 0 0 1rem;',
#  '    z-index: 2;',
#  '    display: none;',
#  '    min-width: 250px;',
#  '\tfont-weight: 800;',
#  '\ttext-transform: uppercase;',
#  '    Transition: .3s;',
#  '}',
#  '',
#  '.festival-menu li ul.sub-menu li a {',
#  '    color: #fff;',
#  '    font-size: 14px;',
#  '    padding: 0 2rem;',
#  '    line-height: 2.5!important;',
#  '    font-weight: 800;',
#  '\t text-transform: uppercase !important;',
#  '    Transition: .3s;',
#  '}',
#  '',
#  '#festival-navbar .dropdown-item:focus, #festival-navbar .dropdown-item:hover {',
#  '    text-decoration: none;',
#  '    background-color:#3b2779; ',
#  '}',
#  '',
#  '.festival-menu li ul.sub-menu li a:hover {',
#  '    color:#ee3a92;',
#  '}',
#  '',
#  '/*footer column title PB fix */',
#  '#colophon .footer-magenta h6 {',
#  '    padding-bottom: 0rem !important;',
#  '}',
#  '',
#  '/* start black history month topic hide */',
#  '.postid-411085 .single-topic .topics-header .swiper-container {',
#  '    display: none;',
#  '}',
#  '/* end black history month topic hide */',
#  '',
#  '',
#  '@media only screen and (max-width: 991px){',
#  '.festival-menu li ul.sub-menu li a {',
#  '    color: #fff!important;',
#  '\t',
#  '\t}',
#  '#menu-festival-2022, #menu-festival-2020{',
#  '    flex-direction:column;',
#  '    justify-content: left;',
#  '\t  right:0;',
#  '',
#  '}',
#  '\t.festival-menu li ul.sub-menu {',
#  '    position: relative;',
#  '    margin-bottom: 0;',
#  '}',
#  '\t.festival-menu .menu-item-has-children>a {',
#  '    justify-content: right;',
#  '}',
#  '\t.festival-menu li a {',
#  '    padding: 10px 10px;',
#  '\t\ttext-align: left;',
#  '}',
#  '\t.festival-menu li ul.sub-menu {',
#  '    background: transparent;',
#  '}',
#  '}',
#  '',
#  '@media screen and (max-width: 767px){',
#  '.festival-menu li ul.sub-menu {',
#  '    position: relative;',
#  '    margin-bottom: 0;',
#  '}',
#  '\t.festival-menu .menu-item-has-children>a {',
#  '    justify-content: right;',
#  '}',
#  '\t\t.festival-menu li a {',
#  '    padding: 10px 10px;',
#  '    text-align: left;',
#  '}',
#  '}\t\t</style>',
#  '\t\t\t</head>',
#  '',
#  '<body class="attachment article-template-default single single-article postid-403295 attachmentid-403295 attachment- wp-embed-responsive article black-women-working-in-tech second-menubar-article singular image-filters-enabled">',
#  '',
#  '<div id="fs-select-footer-remove"></div>',
#  '\t\t<div id="essence_1x1"',
#  '\t\t\t class="ad-position essence_1x1 outofpage dfp-ads-outofpage"',
#  '\t\t\t data-placement-name="essence_1x1"',
#  '\t\t\t data-freestar-ad="__1x1"',
#  '\t>',
#  '\t</div>',
#  '\t<div class="expanded-menu" style="display: none">',
#  '\t<span class="close"><svg class="svg-icon" width="24" height="24" aria-hidden="true" role="img" focusable="false" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M19 6.41L17.59 5 12 10.59 6.41 5 5 6.41 10.59 12 5 17.59 6.41 19 12 13.41 17.59 19 19 17.59 13.41 12z"/><path d="M0 0h24v24H0z" fill="none"/></svg></span>',
#  '\t<div class="logo">',
#  '\t\t<a href="https://www.essence.com/" rel="home">',
class="menu-item menu-item-type-post_type menu-item-object-page menu-item-1092127"><a href="https://www.essence.com/vax-vibes/">VAX &#038; VIBES Louisiana</a></li>',
#  '\t<li id="menu-item-1099761" class="menu-item menu-item-type-custom menu-item-object-custom menu-item-1099761"><a href="https://girlsunited.essence.com/gusummit2021/">Girls United Summit 2021</a></li>',
#  '\t<li id="menu-item-1107036" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-1107036"><a href="https://www.essence.com/shegotnow/">She Got Now</a></li>',
#  '\t<li id="menu-item-1088053" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-1088053"><a href="https://www.essence.com/fashionhouse2021/">Fashion House 2021</a></li>',
#  '\t<li id="menu-item-1091883" class="menu-item menu-item-type-custom menu-item-object-custom menu-item-1091883"><a href="https://girlsunited.essence.com/back-to-school">GU Back To School</a></li>',
#  '\t<li id="menu-item-1070461" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-1070461"><a href="https://www.essence.com/dearblackmen/">Dear Black Men</a></li>',
#  '\t<li id="menu-item-1060141" class="menu-item menu-item-type-custom menu-item-object-custom menu-item-1060141"><a href="/iamspeaking/">I Am Speaking</a></li>',
# ...
#  '\r',
#  '&nbsp;\r',
#  '\r',
#  '<strong>Cierra McDonald</strong>\r',
#  '\r',
#  '<div class = "common-article-sec first-sec">',
#  '  <!--image -->',
#  '  <div class = "d-flex align-items-center justify-content-center">',
#  '\t<div class = "picture gallery-images">',
#  '\t  <img src = "https://www.essence.com/wp-content/uploads/2018/11/Cierra-McDonald_Tech-1024x1024.jpg" alt = "">',
#  '\t  <div class = "quick-social-icon">',
#  '\t\t<a class="js-pintrest-share-btn" rel="noopener" href="https://www.pinterest.com/pin/create/link/?url=https://www.essence.com/cierra-mcdonald_tech/?utm_source=pinterest.com&utm_medium=social&utm_campaign=essence&media=https://www.essence.com/wp-content/uploads/2018/11/Cierra-McDonald_Tech-1024x1024.jpg&description=Cierra McDonald_Tech" target="_blank">',
#  '\t\t<svg class="svg-icon" width="24" height="24" aria-hidden="true" role="img" focusable="false" viewBox="0 0 24 24" version="1.1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><path d="M12.289,2C6.617,2,3.606,5.648,3.606,9.622c0,1.846,1.025,4.146,2.666,4.878c0.25,0.111,0.381,0.063,0.439-0.169 c0.044-0.175,0.267-1.029,0.365-1.428c0.032-0.128,0.017-0.237-0.091-0.362C6.445,11.911,6.01,10.75,6.01,9.668 c0-2.777,2.194-5.464,5.933-5.464c3.23,0,5.49,2.108,5.49,5.122c0,3.407-1.794,5.768-4.13,5.768c-1.291,0-2.257-1.021-1.948-2.277 c0.372-1.495,1.089-3.112,1.089-4.191c0-0.967-0.542-1.775-1.663-1.775c-1.319,0-2.379,1.309-2.379,3.059 c0,1.115,0.394,1.869,0.394,1.869s-1.302,5.279-1.54,6.261c-0.405,1.666,0.053,4.368,0.094,4.604 c0.021,0.126,0.167,0.169,0.25,0.063c0.129-0.165,1.699-2.419,2.142-4.051c0.158-0.59,0.817-2.995,0.817-2.995 c0.43,0.784,1.681,1.446,3.013,1.446c3.963,0,6.822-3.494,6.822-7.833C20.394,5.112,16.849,2,12.289,2"></path></svg>\t\t</a>',
#  '\t  </div>',
#  '\t</div>',
#  '  </div>',
#  '  <!--article desc -->',
#  '  <div class = "picture-desc">',
#  '\t\t\t\t<p class = "pict-ttl">',
#  '\t\t\tCierra McDonald Illustrated by @POPEPHOeNIX\t\t</p>',
#  '\t\t',
#  '\t<p class="pict-text">',
#  '\t\t\t</p>',
#  '  </div>',
#  '</div>',
#  '\r',
#  '\r',
#  '<em>Senior Programming Manager, <a href="http://www.microsoft.com">Microsoft</a></em>\r',
#  '\r',
#  'Who says gaming is just for guys? McDonald has made a name for herself as a game developer in Microsoft’s Xbox Advanced Technology Group, and she maintains there’s room for other Black women to enter that space too. “For those whose passion is in art but who are still interested in pursuing a career in tech, games are a great place to make meaningful contributions to a larger vision or to build your own game that brings your unique point of view to life in a highly interactive medium,” she says. “The industry is thriving, with more creators and more players joining every day, and there are ample untapped—and even undiscovered—opportunities for creative, technological and professional growth.” <a href="https://twitter.com/microsoft">@microsoft</a>\r',
#  '\r',
#  '&nbsp;\r',
#  '\r',
#  '<strong>Amanda Spann</strong>\r',
#  '\r',
#  '<div class = "common-article-sec first-sec">',
#  '  <!--image -->',
#  '  <div class = "d-flex align-items-center justify-content-center">',
#  '\t<div class = "picture gallery-images">',
#  '\t  <img src = "https://www.essence.com/wp-content/uploads/2018/11/Amanda-Spann_Tech-1024x1024.jpg" alt = "">',
#  '\t  <div class = "quick-social-icon">',
#  '\t\t<a class="js-pintrest-share-btn" rel="noopener" href="https://www.pinterest.com/pin/create/link/?url=https://www.essence.com/amanda-spann_tech/?utm_source=pinterest.com&utm_medium=social&utm_campaign=essence&media=https://www.essence.com/wp-content/uploads/2018/11/Amanda-Spann_Tech-1024x1024.jpg&description=Amanda Spann_Tech" target="_blank">',
#  '\t\t<svg class="svg-icon" width="24" height="24" aria-hidden="true" role="img" focusable="false" viewBox="0 0 24 24" version="1.1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><path d="M12.289,2C6.617,2,3.606,5.648,3.606,9.622c0,1.846,1.025,4.146,2.666,4.878c0.25,0.111,0.381,0.063,0.439-0.169 c0.044-0.175,0.267-1.029,0.365-1.428c0.032-0.128,0.017-0.237-0.091-0.362C6.445,11.911,6.01,10.75,6.01,9.668 c0-2.777,2.194-5.464,5.933-5.464c3.23,0,5.49,2.108,5.49,5.122c0,3.407-1.794,5.768-4.13,5.768c-1.291,0-2.257-1.021-1.948-2.277 c0.372-1.495,1.089-3.112,1.089-4.191c0-0.967-0.542-1.775-1.663-1.775c-1.319,0-2.379,1.309-2.379,3.059 c0,1.115,0.394,1.869,0.394,1.869s-1.302,5.279-1.54,6.261c-0.405,1.666,0.053,4.368,0.094,4.604 c0.021,0.126,0.167,0.169,0.25,0.063c0.129-0.165,1.699-2.419,2.142-4.051c0.158-0.59,0.817-2.995,0.817-2.995 c0.43,0.784,1.681,1.446,3.013,1.446c3.963,0,6.822-3.494,6.822-7.833C20.394,5.112,16.849,2,12.289,2"></path></svg>\t\t</a>',
#  '\t  </div>',
#  '\t</div>',
#  '  </div>',
#  '  <!--article desc -->',
#  '  <div class = "picture-desc">',
#  '\t\t\t\t<p class = "pict-ttl">',
#  '\t\t\tAmanda Spann Illustrated by @POPEPHOeNIX\t\t</p>',
#  '\t\t',
#  '\t<p class="pict-text">',
#  '\t\t\t</p>',
#  '  </div>',
#  '</div>',
#  '\r',
#  '\r',
#  'Founder, Happii\r',
#  '\r',
#  'After developing a number of apps, including AfriDate, a dating app for Black singles, Spann launched Happii to help nontechnical entrepreneurs do the same. She was also a cofounder of Blerdology, a social enterprise that organized the first hackathon geared toward African-Americans. “There are a lot of people working behind the scenes to raise funds right now to invest in minority entrepreneurs, and I think there are a lot of people on the ground who are doing the work not just to get these tech\xa0entrepreneurs access to capital but also to educate them and to provide them with guidance and mentorship.” <a href="https://twitter.com/amandaspann">@amandaspann</a>\r',
#  '\r',
#  '&nbsp;\r',
#  '\r',
#  '<strong>Kamilah Taylor</strong>\r',
#  '\r',
#  '<div class = "common-article-sec first-sec">',
#  '  <!--image -->',
#  '  <div class = "d-flex align-items-center justify-content-center">',
#  '\t<div class = "picture gallery-images">',
#  '\t  <img src = "https://www.essence.com/wp-content/uploads/2018/11/Kamilah-Taylor_Tech-1024x1024.jpg" alt = "">',
#  '\t  <div class = "quick-social-icon">',
#  '\t\t<a class="js-pintrest-share-btn" rel="noopener" href="https://www.pinterest.com/pin/create/link/?url=https://www.essence.com/kamilah-taylor_tech/?utm_source=pinterest.com&utm_medium=social&utm_campaign=essence&media=https://www.essence.com/wp-content/uploads/2018/11/Kamilah-Taylor_Tech-1024x1024.jpg&description=Kamilah Taylor_Tech" target="_blank">',
#  '\t\t<svg class="svg-icon" width="24" height="24" aria-hidden="true" role="img" focusable="false" viewBox="0 0 24 24" version="1.1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><path d="M12.289,2C6.617,2,3.606,5.648,3.606,9.622c0,1.846,1.025,4.146,2.666,4.878c0.25,0.111,0.381,0.063,0.439-0.169 c0.044-0.175,0.267-1.029,0.365-1.428c0.032-0.128,0.017-0.237-0.091-0.362C6.445,11.911,6.01,10.75,6.01,9.668 c0-2.777,2.194-5.464,5.933-5.464c3.23,0,5.49,2.108,5.49,5.122c0,3.407-1.794,5.768-4.13,5.768c-1.291,0-2.257-1.021-1.948-2.277 c0.372-1.495,1.089-3.112,1.089-4.191c0-0.967-0.542-1.775-1.663-1.775c-1.319,0-2.379,1.309-2.379,3.059 c0,1.115,0.394,1.869,0.394,1.869s-1.302,5.279-1.54,6.261c-0.405,1.666,0.053,4.368,0.094,4.604 c0.021,0.126,0.167,0.169,0.25,0.063c0.129-0.165,1.699-2.419,2.142-4.051c0.158-0.59,0.817-2.995,0.817-2.995 c0.43,0.784,1.681,1.446,3.013,1.446c3.963,0,6.822-3.494,6.822-7.833C20.394,5.112,16.849,2,12.289,2"></path></svg>\t\t</a>',
#  '\t  </div>',
#  '\t</div>',
#  '  </div>',
#  '  <!--article desc -->',
#  '  <div class = "picture-desc">',
#  '\t\t\t\t<p class = "pict-ttl">',
#  '\t\t\tKamilah Taylor Illustrated by @POPEPHOeNIX\t\t</p>',
#  '\t\t',
#  '\t<p class="pict-text">',
#  '\t\t\t</p>',
#  '  </div>',
#  '</div>',
#  '\r',
#  '\r',
#  'App Developer\r',
#  '\r',
#  'After working as a senior software engineer at LinkedIn, Taylor now divides her time between assisting start-ups develop apps and developing her own. She also contributed to the book Women in Tech. “I’m meeting [more] Black women who are in leadership positions. When I moved to Silicon Valley in 2012, I probably would have struggled to meet one Black woman who was doing any of those things, and now I can easily name dozens and that gives me a lot of hope.” <a href="https://twitter.com/kamilah">@kamilah</a>\r',
#  '\r',
#  '&nbsp;\r',
#  '\r',
#  '<strong>Lauren Washington</strong>\r',
#  '\r',
#  '<div class = "common-article-sec first-sec">',
#  '  <!--image -->',
#  '  <div class = "d-flex align-items-center justify-content-center">',
#  '\t<div class = "picture gallery-images">',
#  '\t  <img src = "https://www.essence.com/wp-content/uploads/2018/11/Lauren-Washington_Tech-1024x1024.jpg" alt = "">',
#  '\t  <div class = "quick-social-icon">',
#  '\t\t<a class="js-pintrest-share-btn" rel="noopener" href="https://www.pinterest.com/pin/create/link/?url=https://www.essence.com/lauren-washington_tech/?utm_source=pinterest.com&utm_medium=social&utm_campaign=essence&media=https://www.essence.com/wp-content/uploads/2018/11/Lauren-Washington_Tech-1024x1024.jpg&description=Lauren Washington_Tech" target="_blank">',
#  '\t\t<svg class="svg-icon" width="24" height="24" aria-hidden="true" role="img" focusable="false" viewBox="0 0 24 24" version="1.1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><path d="M12.289,2C6.617,2,3.606,5.648,3.606,9.622c0,1.846,1.025,4.146,2.666,4.878c0.25,0.111,0.381,0.063,0.439-0.169 c0.044-0.175,0.267-1.029,0.365-1.428c0.032-0.128,0.017-0.237-0.091-0.362C6.445,11.911,6.01,10.75,6.01,9.668 c0-2.777,2.194-5.464,5.933-5.464c3.23,0,5.49,2.108,5.49,5.122c0,3.407-1.794,5.768-4.13,5.768c-1.291,0-2.257-1.021-1.948-2.277 c0.372-1.495,1.089-3.112,1.089-4.191c0-0.967-0.542-1.775-1.663-1.775c-1.319,0-2.379,1.309-2.379,3.059 c0,1.115,0.394,1.869,0.394,1.869s-1.302,5.279-1.54,6.261c-0.405,1.666,0.053,4.368,0.094,4.604 c0.021,0.126,0.167,0.169,0.25,0.063c0.129-0.165,1.699-2.419,2.142-4.051c0.158-0.59,0.817-2.995,0.817-2.995 c0.43,0.784,1.681,1.446,3.013,1.446c3.963,0,6.822-3.494,6.822-7.833C20.394,5.112,16.849,2,12.289,2"></path></svg>\t\t</a>',
#  '\t  </div>',
#  '\t</div>',
#  '  </div>',
#  '  <!--article desc -->',
#  '  <div class = "picture-desc">',
#  '\t\t\t\t<p class = "pict-ttl">',
#  '\t\t\tLauren Washington Illustrated by @POPEPHOeNIX\t\t</p>',
#  '\t\t',
#  '\t<p class="pict-text">',
#  '\t\t\t</p>',
#  '  </div>',
#  '</div>',
#  '\r',
#  '\r',
#  '<em>CoFounder, KeepUp; CoFounder, <a href="https://www.blackwomentalktech.com/">Black Women Talk Tech</a></em>\r',
#  '\r',
#  'From her vantage point in online marketing and advertising, Washington watched how overwhelming navigating the social media landscape can be, so she created the KeepUp app to help companies and individuals manage it. She is one of three cofounders of Black Women Talk Tech, an organization that supports the next generation of tech founders in our community. “There are Black women who have raised less than $100,000 and are making millions of dollars in revenue,” she says. “With the push for diversity in tech, people are coming together in order to build each other up, so there’s no better time.” <a href="https://twitter.com/bwtalktech">@bwtalktech</a>\r',
#  '\r',
#  '&nbsp;\r',
#  '\r',
#  '<strong>Tishauna Wilson</strong>\r',
#  '\r',
#  '<div class = "common-article-sec first-sec">',
#  '  <!--image -->',
#  '  <div class = "d-flex align-items-center justify-content-center">',
#  '\t<div class = "picture gallery-images">',
#  '\t  <img src = "https://www.essence.com/wp-content/uploads/2018/11/Tishauna-Wilson_Tech-1024x1024.jpg" alt = "">',
#  '\t  <div class = "quick-social-icon">',
#  '\t\t<a class="js-pintrest-share-btn" rel="noopener" href="https://www.pinterest.com/pin/create/link/?url=https://www.essence.com/tishauna-wilson_tech/?utm_source=pinterest.com&utm_medium=social&utm_campaign=essence&media=https://www.essence.com/wp-content/uploads/2018/11/Tishauna-Wilson_Tech-1024x1024.jpg&description=Tishauna Wilson_Tech" target="_blank">',
#  '\t\t<svg class="svg-icon" width="24" height="24" aria-hidden="true" role="img" focusable="false" viewBox="0 0 24 24" version="1.1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><path d="M12.289,2C6.617,2,3.606,5.648,3.606,9.622c0,1.846,1.025,4.146,2.666,4.878c0.25,0.111,0.381,0.063,0.439-0.169 c0.044-0.175,0.267-1.029,0.365-1.428c0.032-0.128,0.017-0.237-0.091-0.362C6.445,11.911,6.01,10.75,6.01,9.668 c0-2.777,2.194-5.464,5.933-5.464c3.23,0,5.49,2.108,5.49,5.122c0,3.407-1.794,5.768-4.13,5.768c-1.291,0-2.257-1.021-1.948-2.277 c0.372-1.495,1.089-3.112,1.089-4.191c0-0.967-0.542-1.775-1.663-1.775c-1.319,0-2.379,1.309-2.379,3.059 c0,1.115,0.394,1.869,0.394,1.869s-1.302,5.279-1.54,6.261c-0.405,1.666,0.053,4.368,0.094,4.604 c0.021,0.126,0.167,0.169,0.25,0.063c0.129-0.165,1.699-2.419,2.142-4.051c0.158-0.59,0.817-2.995,0.817-2.995 c0.43,0.784,1.681,1.446,3.013,1.446c3.963,0,6.822-3.494,6.822-7.833C20.394,5.112,16.849,2,12.289,2"></path></svg>\t\t</a>',
#  '\t  </div>',
#  '\t</div>',
#  '  </div>',
#  '  <!--article desc -->',
#  '  <div class = "picture-desc">',
#  '\t\t\t\t<p class = "pict-ttl">',
#  '\t\t\tTishauna Wilson Illustrated by @POPEPHOeNIX\t\t</p>',
#  '\t\t',
#  '\t<p class="pict-text">',
#  '\t\t\t</p>',
#  '  </div>',
#  '</div>',
#  '\r',
#  '\r',
#  '<em>Computer Science student</em>\r',
#  '\r',
#  'Although she’s still a junior at Florida A&amp;M University, Wilson is already shaking things up in the industry. This year she won a $10,000 scholarship as part of McDonald’s 365 Black Awards for her tech projects, which include a self-driving, voice-activated drone and an artificial intelligence program that would detect credit card fraud. “I think the visibility of Black women will persuade more young Black girls to look at technology,” says Wilson. “As they see more of us, they’ll be more encouraged to pursue it.” <a href="https://www.instagram.com/shauna813_/">@shauna813_</a>\r',
#  '\r',
#  '&nbsp;',
#  '\t\t\t<p><span class="tags-links"><span class="topics">TOPICS:&nbsp; </span> <a href="https://www.essence.com/tags/black-women-working-in-tech/" rel="tag">Black Women Working In Tech</a> <a href="https://www.essence.com/tags/careers/" rel="tag">Careers</a></span>',
#  '</p><div data-source="1" id=\'jw-video-box-am403295\' class=\'ess-embed-content jw-video-box\' data-video=\'am403295\' data-player_id=\'96LVqmRJ\' itemprop="video" itemscope itemtype="https://schema.org/VideoObject">',
#  '\t',
#  '\t\t<meta itemprop="thumbnailUrl" content="https://cdn.jwplayer.com/v2/media/Gvdqytz5/poster.jpg?width=720"/>',
#  '\t\t<meta itemprop="uploadDate" content="2021-08-03T20:02:00Z"/>',
#  '\t\t<meta itemprop="description" content="Black women winning in the 2020 Olympics. "/>',
#  '\t\t<meta itemprop="name" content="Black Women Winning in Tokyo"/>',
#  '\t\t<meta itemprop="contentUrl" content="https://cdn.jwplayer.com/videos/Gvdqytz5-3hXWaTVp.mp4"/>',
#  '',
#  "\t\t\t<div id='jw-video-am403295'>",
#  '\t\tLoading the player...\t</div>',
#  "\t<script type='text/javascript'>",
#  '\t\tvar playerInstance_am403295 = jwplayer("jw-video-am403295").setup({',
#  '\t\t\tplaylist: "https://cdn.jwplayer.com/v2/playlists/ZxLfsoGK?search=The%20Future%2010:%20Get%20To%20Know%20These%2010%20Black%20Women%20In%20Tech&#038;page_description=",',
#  '\t\t\tautostart: false,',
#  '\t\t\trepeat: true,',
#  '\t\t\tmute: true,',
#  "\t\t\taspectratio: '16:9',",
#  '\t\t\tsharing: { sites: ["facebook","twitter","email","linkedin"] },',
#  '\t\t\tcast: {},',
#  '\t\t\tfloating: { dismissible: true },',
#  '\t\t\tautoPause: { viewability: false },',
#  '\t\t\tdisplaytitle: true,',
#  '\t\t\tdisplaydescription: true,',
#  '\t\t\tcontrols: true,',
#  "\t\t\trelated: { displayMode: 'shelfWidget' },",
#  ...]

# %%
# targeting substring to get list of names
for line in html.split('\n'):
    if 'strong' in line:
        print(line)
# Out:
# <strong>Kathryn Finney</strong>
# <strong>Regina Gwynn</strong>
# <strong>Camille Hearst</strong>
# <strong>Esosa Ighodaro</strong>
# <strong>Jasmine Lawrence</strong>
# <strong>Cierra McDonald</strong>
# <strong>Amanda Spann</strong>
# <strong>Kamilah Taylor</strong>
# <strong>Lauren Washington</strong>
# <strong>Tishauna Wilson</strong>

# %%
# removing non-name text
for line in html.split('\n'):
    if 'strong' in line:
        print(line.replace('<strong>', '').replace('</strong>', ''))
# Out:
# Kathryn Finney
# Regina Gwynn
# Camille Hearst
# Esosa Ighodaro
# Jasmine Lawrence
# Cierra McDonald
# Amanda Spann
# Kamilah Taylor
# Lauren Washington
# Tishauna Wilson

# %%
# saving names to text file
with open('black-women-in-tech_names.txt', 'w') as write_names:
    for line in html.split('\n'):
        if 'strong' in line:
            #saving each names to list var
            names = line.replace('<strong>', '').replace('</strong>', '')
            
            #adding each name to text file
            write_names.write(names)
            
            #separating each name to its own line
            write_names.write('\n')

# %%
# verifying names added to file correctly by reading in text file to df
pd.read_csv('black-women-in-tech_names.txt')
# Out:
#       Kathryn Finney
# 0       Regina Gwynn
# 1     Camille Hearst
# 2     Esosa Ighodaro
# 3   Jasmine Lawrence
# 4    Cierra McDonald
# 5       Amanda Spann
# 6     Kamilah Taylor
# 7  Lauren Washington
# 8    Tishauna Wilson
